# %% [markdown]
# # Master table quick exploration
#
# Lightweight exploratory notebook for the NOGSE pipeline master table.
#
# Main use cases:
#
# - Inspect selected columns with pandas.
# - Plot OGSE signal versus `g_thorsten`.
# - Plot contrast versus `g_thorsten`.
# - Compare all contrasts across `td_ms`, with `long` and `tra` directions side by side.
#
# The notebook intentionally keeps the logic simple and local so that new analysis blocks can be appended incrementally.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 200)
pd.set_option("display.width", 160)

# %% [markdown]
# ## 1. Load the master table
#
# Adjust `MASTER_PATH` if your table lives elsewhere. Prefer parquet for speed; xlsx is supported for quick manual exports.

# %%
MASTER_PATH = Path("../../analysis/brains/ogse_experiments/master.long.parquet")

print("Current directory:", Path.cwd())
print("Master path:", MASTER_PATH.resolve())
print("Exists:", MASTER_PATH.exists())
# Out:
# Current directory: /mnt/storage/tier2/MUMI-EXT-001/mumi-data/Project-Balseiro-Microstructure/nogse_pipeline/notebooks
# Master path: /mnt/storage/tier2/MUMI-EXT-001/mumi-data/Project-Balseiro-Microstructure/analysis/brains/ogse_experiments/master.long.parquet
# Exists: True

# %%
df = pd.read_parquet(MASTER_PATH)

print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns):,}")

df.head()
# Out:
# Rows: 183,920
# Columns: 46
#   row_kind                                        analysis_id   subj           sheet    roi direction stat  b_step       value  value_norm    D_proj  \
# 0   signal  signal_subj-BRAIN_sheet-20220622_BRAIN_type-PG...  BRAIN  20220622_BRAIN  AntCC         1  avg       0  250.646158    1.000000       NaN
# 1   signal  signal_subj-BRAIN_sheet-20220622_BRAIN_type-PG...  BRAIN  20220622_BRAIN  AntCC         1  avg       1  227.086068    0.906003  0.004936
# 2   signal  signal_subj-BRAIN_sheet-20220622_BRAIN_type-PG...  BRAIN  20220622_BRAIN  AntCC         1  avg       2  195.928817    0.781695  0.003079
# 3   signal  signal_subj-BRAIN_sheet-20220622_BRAIN_type-PG...  BRAIN  20220622_BRAIN  AntCC         1  avg       3  166.929024    0.665995  0.002258
# 4   signal  signal_subj-BRAIN_sheet-20220622_BRAIN_type-PG...  BRAIN  20220622_BRAIN  AntCC         1  avg       4  137.190440    0.547347  0.001883
#
#    grad_correction_factor  alpha_macro  td_ms  N   Hz                                        source_file source_path source_hash  bvalue  bvalue_orig  \
# 0                     NaN          NaN   90.0  1  0.0  20220622_BRAIN_ep2d_advdiff_AP_919D_OGSE_10bva...        None        None     0.0          0.0
# 1                     NaN          NaN   90.0  1  0.0  20220622_BRAIN_ep2d_advdiff_AP_919D_OGSE_10bva...        None        None    20.0         20.0
# 2                     NaN          NaN   90.0  1  0.0  20220622_BRAIN_ep2d_advdiff_AP_919D_OGSE_10bva...        None        None    80.0         80.0
# 3                     NaN          NaN   90.0  1  0.0  20220622_BRAIN_ep2d_advdiff_AP_919D_OGSE_10bva...        None        None   180.0        180.0
# 4                     NaN          NaN   90.0  1  0.0  20220622_BRAIN_ep2d_advdiff_AP_919D_OGSE_10bva...        None        None   320.0        320.0
#
#    bvalue_g  bvalue_g_lin_max  bvalue_thorsten    bmax         g      g_max  g_lin_max  g_thorsten gradient_axis_kind  one_g_per_sequence          S0     TE  \
# 0       0.0               0.0         0.000000  2000.0  0.000000  21.382748   0.000000    0.000000                  b               False  250.646158  117.0
# 1      20.0              20.0        19.947426  2000.0  2.138275  21.382748   2.138275    2.135462                  b               False  250.646158  117.0
# 2      80.0              80.0        79.789703  2000.0  4.276550  21.382748   4.276550    4.270925                  b               False  250.646158  117.0
# 3     180.0             180.0       179.526832  2000.0  6.414824  21.382748   6.414824    6.406387                  b               False  250.646158  117.0
# 4     320.0             320.0       319.158812  2000.0  8.553099  21.382748   8.553099    8.541850                  b               False  250.646158  117.0
#
#        TR  max_dur_ms  Delta_app_ms  delta_ms  tm_ms  TN   G   x   y            type  sequence group                  protocol
# 0  6000.0        40.0          38.2      40.0   10.0 NaN NaN NaN NaN  PGSE monopolar       5.0  None  20220617_GONZANY_ADVDIFF
# 1  6000.0        40.0          38.2      40.0   10.0 NaN NaN NaN NaN  PGSE monopolar       5.0  None  20220617_GONZANY_ADVDIFF
# 2  6000.0        40.0          38.2      40.0   10.0 NaN NaN NaN NaN  PGSE monopolar       5.0  None  20220617_GONZANY_ADVDIFF
# 3  6000.0        40.0          38.2      40.0   10.0 NaN NaN NaN NaN  PGSE monopolar       5.0  None  20220617_GONZANY_ADVDIFF
# 4  6000.0        40.0          38.2      40.0   10.0 NaN NaN NaN NaN  PGSE monopolar       5.0  None  20220617_GONZANY_ADVDIFF

# %% [markdown]
# ## 2. Quick inventory

# %%
def show_unique_values(df: pd.DataFrame, columns: list[str], max_values: int = 100) -> None:
    """Print compact unique-value summaries for selected columns."""
    for col in columns:
        if col not in df.columns:
            print(f"\n{col}: <missing>")
            continue

        values = df[col].dropna().unique()
        values = sorted(values, key=lambda x: str(x))
        preview = values[:max_values]
        print(f"\n{col} ({len(values)} unique):")
        print(preview)


show_unique_values(
    df,
    [
        "row_kind",
        "subj",
        "sheet",
        "roi",
        "direction",
        "stat",
        "N",
        # "N_1",
        # "N_2",
        "td_ms",
        # "Hz",
        # "Hz_1",
        # "Hz_2",
        "type",
    ],
)
# Out:
# row_kind (2 unique):
# ['signal', 'signal_rotated']
#
# subj (3 unique):
# ['BRAIN', 'LUDG', 'MBBL']
#
# sheet (7 unique):
# ['20220622_BRAIN', '20230619_BRAIN-3', '20230623_BRAIN-4', '20230623_LUDG-2', '20230629_MBBL-2', '20230630_MBBL-3', '20230710_LUDG-3']
#
# roi (8 unique):
# ['AntCC', 'CentralCC', 'Left-Lateral-Ventricle', 'MidAntCC', 'MidPostCC', 'PostCC', 'Right-Lateral-Ventricle', 'Syringe']
#
# direction (14 unique):
# ['1', '2', '3', '4', '5', '6', 'eig1', 'eig2', 'eig3', 'long', 'tra', 'x', 'y', 'z']
#
# stat (5 unique):
# ['avg', 'mad', 'med', 'mode', 'std']
#
# N (8 unique):
# [np.int64(1), np.int64(12), np.int64(16), np.int64(20), np.int64(24), np.int64(28), np.int64(4), np.int64(8)]
#
# td_ms (5 unique):
# [np.float64(120.0), np.float64(143.4), np.float64(210.0), np.float64(76.0), np.float64(90.0)]
#
# type (2 unique):
# ['OGSE (cos)', 'PGSE monopolar']

# %% [markdown]
# ## 3. Small filtering helpers

# %%
def select_rows(df, row_kind, subj, roi, direction, stat="avg", N=None, td_ms=None, D_proj=None):
    """Select rows from the master table using the main filters."""
    return df[
        (df["row_kind"] == row_kind) &
        (df["subj"] == subj) &
        (df["roi"] == roi) &
        (df["direction"] == str(direction)) &
        (df["stat"] == stat) &
        (df["N"] == N) &
        (df["td_ms"] == td_ms)
    ].copy()

# %% [markdown]
# ## 4. Quick pandas table selection
#
# Edit the variables below to inspect a specific ROI/subject/direction.

# %%
df = pd.read_parquet(MASTER_PATH)
MASTER_PATH = Path("../../analysis/brains/ogse_experiments/master.long.parquet")

subj = "MBBL"
roi = "AntCC"  # Example ROI; change as needed
td_ms =  210.0# Example td_ms; change as needed
dir = "long"
signal = select_rows(
    df,
    row_kind="signal_rotated", #signal, signal_rotated, dproj
    subj=subj,
    roi=roi,
    N=4,
    td_ms=td_ms,
    direction=dir,
    stat="avg",
    # D_proj="D_proj"
)

signal1 = select_rows(
    df,
    row_kind="signal_rotated", #signal, signal_rotated, dproj
    subj=subj,
    roi=roi,
    N=8,
    td_ms=td_ms,
    direction=dir,
    stat="avg",
    # D_proj="D_proj"
)

print("ROI:", roi)
n4 = 3
n8 = 3

mean_n4 = signal["value"].tail(n4).mean()
mean_n8 = signal1["value"].tail(n8).mean()

sem_n4 = signal["value"].tail(n4).std() / np.sqrt(n4)
sem_n8 = signal1["value"].tail(n8).std() / np.sqrt(n8)

mean_difference = mean_n4 - mean_n8
combined_sem = np.sqrt(sem_n4**2 + sem_n8**2)
standardized_difference = mean_difference / combined_sem

print(subj)
print(td_ms)
print("Tail N=4:", mean_n4, "+-", sem_n4)
print("Tail N=8:", mean_n8, "+-", sem_n8)
print("Absolute difference:", mean_difference)
print("Combined SEM:", combined_sem)
print("Standardized difference:", standardized_difference)

print("\nFull data for N=4 and N=8:")
print("N=4")
print(signal[["row_kind", "subj", "roi", "value", "value_norm", "g_thorsten", "D_proj", "N", "td_ms", "Hz", "b_step"]])
print("--------------------------------------------------")
print("N=8")
print(signal1[["row_kind", "subj", "roi", "value", "value_norm", "g_thorsten", "D_proj", "N", "td_ms", "Hz", "b_step"]])
# Out:
# ROI: AntCC
# MBBL
# 210.0
# Tail N=4: 35.18685651259876 +- 0.48218397001699315
# Tail N=8: 35.82558749294819 +- 0.5997618758656035
# Absolute difference: -0.638730980349429
# Combined SEM: 0.7695555137111136
# Standardized difference: -0.8299998752126473
#
# Full data for N=4 and N=8:
# N=4
#               row_kind  subj    roi       value  value_norm  g_thorsten    D_proj  N  td_ms    Hz  b_step
# 176605  signal_rotated  MBBL  AntCC  111.555940    1.000000    0.000000       NaN  4  210.0  10.0       0
# 176606  signal_rotated  MBBL  AntCC   90.842409    0.814322    5.190164  0.002563  4  210.0  10.0       1
# 176607  signal_rotated  MBBL  AntCC   65.165405    0.584150   10.380328  0.001677  4  210.0  10.0       2
# 176608  signal_rotated  MBBL  AntCC   43.235304    0.387566   15.570491  0.001314  4  210.0  10.0       3
# 176609  signal_rotated  MBBL  AntCC   35.061795    0.314298   20.760655  0.000903  4  210.0  10.0       4
# 176610  signal_rotated  MBBL  AntCC   37.240272    0.333826   25.950819  0.000548  4  210.0  10.0       5
# 176611  signal_rotated  MBBL  AntCC   35.803115    0.320943   31.140983  0.000394  4  210.0  10.0       6
# 176612  signal_rotated  MBBL  AntCC   37.488136    0.336048   36.331146  0.000278  4  210.0  10.0       7
# 176613  signal_rotated  MBBL  AntCC   34.271441    0.307213   41.521310  0.000230  4  210.0  10.0       8
# 176614  signal_rotated  MBBL  AntCC   35.381857    0.317167   46.711474  0.000177  4  210.0  10.0       9
# 176615  signal_rotated  MBBL  AntCC   35.907272    0.321877   51.901638  0.000141  4  210.0  10.0      10
# --------------------------------------------------
# N=8
#               row_kind  subj    roi       value  value_norm  g_thorsten    D_proj  N  td_ms    Hz  b_step
# 179949  signal_rotated  MBBL  AntCC  116.200549    1.000000    0.000000       NaN  8  210.0  20.0       0
# 179950  signal_rotated  MBBL  AntCC  110.003273    0.946667    6.406387  0.001815  8  210.0  20.0       1
# 179951  signal_rotated  MBBL  AntCC   88.848491    0.764613   12.812775  0.002222  8  210.0  20.0       2
# 179952  signal_rotated  MBBL  AntCC   70.624198    0.607779   19.219162  0.001832  8  210.0  20.0       3
# 179953  signal_rotated  MBBL  AntCC   49.300517    0.424271   25.625550  0.001774  8  210.0  20.0       4
# 179954  signal_rotated  MBBL  AntCC   43.299932    0.372631   32.031937  0.001308  8  210.0  20.0       5
# 179955  signal_rotated  MBBL  AntCC   36.211349    0.311628   38.438325  0.001072  8  210.0  20.0       6
# 179956  signal_rotated  MBBL  AntCC   36.104696    0.310710   44.844712  0.000790  8  210.0  20.0       7
# 179957  signal_rotated  MBBL  AntCC   34.636225    0.298073   51.251100  0.000626  8  210.0  20.0       8
# 179958  signal_rotated  MBBL  AntCC   36.555194    0.314587   57.657487  0.000473  8  210.0  20.0       9
# 179959  signal_rotated  MBBL  AntCC   36.285344    0.312265   64.063874  0.000385  8  210.0  20.0      10

# %% [markdown]
# ## 5. Plot OGSE signal versus `g_thorsten`
#
# This is intended for one signal curve, selected by subject, ROI, direction, `N`, and optionally `td_ms` or `Hz`.

# %%
# Parameters
subj = "BRAIN"
roi = "CentralCC"
direction = "long"
stat = "avg"
N1 = 8
N2 = 4
N3 = 12
td_ms = 143.4

gamma = 267.5221900   # rad / (ms · mT), proton gyromagnetic ratio
D0    = 3.2e-12 

# Select one signal curve
signal1 = df[
    (df["row_kind"] == "signal_rotated") &
    (df["subj"] == subj) &
    (df["roi"] == roi) &
    (df["direction"].astype(str) == str(direction)) &
    (df["stat"] == stat) &
    (df["N"] == N1) &
    (np.isclose(pd.to_numeric(df["td_ms"], errors="coerce"), td_ms))
].copy()

signal2 = df[
    (df["row_kind"] == "signal_rotated") &
    (df["subj"] == subj) &
    (df["roi"] == roi) &
    (df["direction"].astype(str) == str(direction)) &
    (df["stat"] == stat) &
    (df["N"] == N2) &
    (np.isclose(pd.to_numeric(df["td_ms"], errors="coerce"), td_ms))
].copy()

signal3 = df[
    (df["row_kind"] == "signal_rotated") &
    (df["subj"] == subj) &
    (df["roi"] == roi) &
    (df["direction"].astype(str) == str(direction)) &
    (df["stat"] == stat) &
    (df["N"] == N3) &
    (np.isclose(pd.to_numeric(df["td_ms"], errors="coerce"), td_ms))
].copy()

signal1 = signal1.dropna(subset=["g_thorsten", "value_norm"])
signal2 = signal2.dropna(subset=["g_thorsten", "value_norm"])
signal3 = signal3.dropna(subset=["g_thorsten", "value_norm"])
# contrast = signal1["value_norm"].values - signal2["value_norm"].values

l_d = np.sqrt(D0 * float(td_ms))

l_G_1 = (D0 / (gamma * signal1["g_thorsten"])) ** (1.0 / 3.0)
Ld_1  = l_d / l_G_1

l_G_2 = (D0 / (gamma * signal2["g_thorsten"])) ** (1.0 / 3.0)
Ld_2  = l_d / l_G_2

l_G_3 = (D0 / (gamma * signal3["g_thorsten"])) ** (1.0 / 3.0)
Ld_3  = l_d / l_G_3

plt.figure(figsize=(6, 4))

plt.plot((Ld_1**6)/(12*N1**2), signal1["value_norm"], "o-", label=f"N={N1}")
plt.plot((Ld_1**6)/(12*N2**2), signal2["value_norm"], "o-", label=f"N={N2}")
plt.plot((Ld_1**6)/(12*N3**2), signal3["value_norm"], "o-", label=f"N={N3}")

# plt.plot(signal1["g_thorsten"], signal1["value_norm"], "o-", label=f"N={N1}")
# plt.plot(signal2["g_thorsten"], signal2["value_norm"], "o-", label=f"N={N2}")
# plt.plot(signal1["g_thorsten"], contrast, "o-", label="contrast")
plt.title(f"{subj}, {roi}, dir={direction}, td={td_ms:.1f} ms")
plt.xlabel(r"Ls = $\frac{L_d^6}{12 N^2}$")
plt.ylabel("value")
#plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Plot contrast versus `g_thorsten`
#
# This assumes contrast rows are stored in the master table with `row_kind == "contrast"`.

# %% [markdown]
# ## 7. All contrast curves across `td_ms`: long left, tra right

# %%
# Parameters
subj = "BRAIN"
roi = "AntCC"
direction = "1"
stat = "avg"
N1 = 8
N2 = 4
td_ms = 90.0

# Select one contrast curve
contrast = df[
    (df["row_kind"] == "contrast") &
    (df["subj"] == subj) &
    (df["roi"] == roi) &
    (df["direction"].astype(str) == str(direction)) &
    (df["stat"] == stat) &
    (df["N_1"] == N1) &
    (df["N_2"] == N2) &
    (np.isclose(pd.to_numeric(df["td_ms"], errors="coerce"), td_ms))
].copy()

contrast = contrast.dropna(subset=["g_thorsten", "value_norm"])
contrast = contrast.sort_values("g_thorsten")

print("Rows:", len(contrast))

plt.figure(figsize=(6, 4))
plt.plot(contrast["g_thorsten"], contrast["value_norm"], "o-", label=f"N={N1} - N={N2}")
plt.title(f"{subj}, {roi}, dir={direction}, td={td_ms:.1f} ms")
plt.xlabel("g_thorsten [mT/m]")
plt.ylabel("contrast value_norm")
plt.legend()
plt.grid(True)
plt.show()

contrast[["g_thorsten", "value_norm", "b_step", "td_ms", "N_1", "N_2", "source_file"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/nogse_pipe_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'N_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 17
#      13     (df["subj"] == subj) &
#      14     (df["roi"] == roi) &
#      15     (df["direction"].astype(str) == str(direction)) &
#      16     (df["stat"] == stat) &
# ---> 17     (df["N_1"] == N1) &
#      18     (df["N_2"] == N2) &
#      19     (np.isclose(pd.to_numeric(df["td_ms"], errors="coerce"), td_ms))
#      20 ].copy()
#
# File ~/.conda/envs/nogse_pipe_env/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/.conda/envs/nogse_pipe_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'N_1'

# %% [markdown]
# ## 8. Small reusable snippets
#
# Copy and adapt these cells when adding new quick analyses.

# %%
# Example: inspect only two columns for one ROI/subject/direction.
quick_table = select_table(
    df,
    row_kind="signal",
    subj="BRAIN",
    roi="AntCC",
    direction="1",
    stat="avg",
    columns=["value_norm", "g_thorsten"],
)

quick_table.head(20)

# %%
# Example: get all available td_ms values for a specific contrast selection.
td_available = (
    select_table(
        df,
        row_kind="contrast",
        subj="BRAIN",
        roi="AntCC",
        direction="long",
        stat="avg",
        columns=["td_ms"],
        N_1=8,
        N_2=4,
    )["td_ms"]
    .dropna()
    .sort_values()
    .unique()
)

td_available
