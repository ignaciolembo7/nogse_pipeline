# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.lines as mlines
from scipy.optimize import least_squares

sys.path.insert(0, str(Path("../../nogse_pipeline/src")))
from models.model_fitting import M_ogse_rest
from plotting.publication.tc_param_vars import _roi_color_map, DEFAULT_BRAIN_MARKERS

# %%
MASTER_PATH  = Path("../../analysis/brains/ogse_experiments/master.long.parquet")
OUT_DIR      = Path("../../analysis/brains/ogse_experiments/lab/fit_rest-a1")
OUT_DIR.mkdir(parents=True, exist_ok=True)

DIRECTIONS  = ["tra", "long"]
N_LIST      = [4, 8]
TD_LIST     = None
ROI_LIST    = ["AntCC", "MidAntCC", "CentralCC", "MidPostCC", "PostCC"]      # None -> all ROIs; list of strings -> e.g. [ "PostCC", "Left-Lateral-Ventricle"]
# ROI_LIST    = ["Left-Lateral-Ventricle", "Right-Lateral-Ventricle"]
# ROI_LIST    = ["Syringe"]
G_COLUMN    = "g_thorsten"
G_CORRECTION_COLUMN = "grad_correction_factor"
Y_COLUMN    = "value"         # "value" or "value_norm"
D0_FIXED    = 3.0e-12         # m²/ms, fixed

TC_FIXED    = None            # None → fitted per curve; float → pinned [ms]
TC_INIT     = 5.0             # ms, initial seed
TC_BOUNDS   = (0.05, 1000.0)  # ms

# TC_GLOBAL scope — how broadly tc is shared:
#   None          → per-curve independent fits (one tc per td, N, direction)
#   "direction"   → one tc per (subj, roi, direction), shared across td & N
#   "roi"         → one tc per (subj, roi), shared across td, N & direction
#   "subj"        → one tc per subj, shared across td, N, direction & roi
#   "all"         → one tc for all data
TC_GLOBAL   = None

M0_FIXED    = None
M0_BOUNDS   = (0.0, 2000.0)
M0_INIT_FRACTION = 0.9        # M0 init = M0_INIT_FRACTION * y.max()
RN_FIXED    = None      # Rician noise floor (in raw signal units):
                        #   None                 → fitted per td
                        #   float                → fixed for all subj and td
                        #   {td: float}          → fixed per td, same for all subj
                        #   {subj: float}        → fixed per subj, same for all td
                        #   {subj: {td: float}}  → fixed per subj and td
RN_FIXED = {
    "BRAIN": {76.0: 37.0, 90.0: 34.0, 120.0: 36.0, 143.4: 36.0, 210.0: 37.0},
    "LUDG":  {90.0: 31.0, 120.0: 30.0, 143.4: 30.0, 210.0: 31.0},
    "MBBL":  {90.0: 35.0, 120.0: 31.0, 143.4: 31.0, 210.0: 35.0},
}
        
RN_INIT     = 10.0
RN_BOUNDS   = (0.0, 500.0)
# RN_GLOBAL scope:
#   "td"  → one RN per (subj, roi, dir, td), shared across N
#   None  → per-curve
RN_GLOBAL   = "td"

MODEL_NAME = 'rest'

# %%
df = pd.read_parquet(MASTER_PATH)

data = df[
    (df.row_kind == "signal_rotated") &
    (df.direction.isin(DIRECTIONS)) &
    (df.N.isin(N_LIST)) &
    (df.stat == "avg")
].copy()

missing_cols = [col for col in [G_COLUMN, Y_COLUMN, G_CORRECTION_COLUMN] if col is not None and col not in data.columns]
if missing_cols:
    raise KeyError(f"Missing selected column(s) in data: {missing_cols}")

data["G_fit"] = data[G_COLUMN]
if G_CORRECTION_COLUMN is not None:
    data["G_fit"] = data["G_fit"] * data[G_CORRECTION_COLUMN]
data["y_raw"] = data["value"]   # raw signal (a.u.) — always needed to derive M0 from S0 and RN
data["y_fit"] = data[Y_COLUMN]

G_LABEL = f"Modulation gradient strength G [mT/m] ({G_COLUMN})"
Y_LABEL = f"{Y_COLUMN} [a.u.]"

if TD_LIST is not None:
    data = data[data.td_ms.isin(TD_LIST)]
if ROI_LIST is not None:
    data = data[data.roi.isin(ROI_LIST)]

print(f"Rows loaded: {len(data)}")
print("Groups (subj, roi, dir):", data.groupby(["subj", "roi", "direction"]).ngroups)
print(f"Gradient for fit: {G_COLUMN}" + (f" * {G_CORRECTION_COLUMN}" if G_CORRECTION_COLUMN else ""))
print(f"Signal for fit: {Y_COLUMN}")
data[["subj", "roi", "direction", "td_ms", "N", "G_fit", "y_fit"]]
# Out:
# Rows loaded: 2860
# Groups (subj, roi, dir): 30
# Gradient for fit: g_thorsten * grad_correction_factor
# Signal for fit: value
#          subj     roi direction  td_ms  N      G_fit       y_fit
# 5302    BRAIN   AntCC       tra   90.0  4   0.000000  250.168675
# 5303    BRAIN   AntCC       tra   90.0  4   6.213986  244.684694
# 5304    BRAIN   AntCC       tra   90.0  4  12.427971  228.825266
# 5305    BRAIN   AntCC       tra   90.0  4  18.641957  214.273122
# 5306    BRAIN   AntCC       tra   90.0  4  24.855943  194.742588
# ...       ...     ...       ...    ... ..        ...         ...
# 180395   MBBL  PostCC      long  210.0  8  35.446824   52.056472
# 180396   MBBL  PostCC      long  210.0  8  41.354627   50.485129
# 180397   MBBL  PostCC      long  210.0  8  47.262431   51.328731
# 180398   MBBL  PostCC      long  210.0  8  53.170235   52.411720
# 180399   MBBL  PostCC      long  210.0  8  59.078039   50.391365
#
# [2860 rows x 7 columns]

# %%
def _resolve_rn(subj, td):
    """Return the fixed RN for (subj, td), or None when RN_FIXED is None (→ fitted).
    RN_FIXED may be: None → free; float → global;
    {td: float} → per td; {subj: float} → per subj; {subj: {td: float}} → per subj and td.
    """
    if RN_FIXED is None:
        return None
    if isinstance(RN_FIXED, dict):
        first_key = next(iter(RN_FIXED))
        if isinstance(first_key, str):
            subj_entry = RN_FIXED.get(subj)
            if subj_entry is None:
                return 0.0
            if isinstance(subj_entry, dict):
                return float(subj_entry.get(float(td), subj_entry.get(td, 0.0)))
            return float(subj_entry)
        return float(RN_FIXED.get(float(td), RN_FIXED.get(td, 0.0)))
    return float(RN_FIXED)


def _m0_from_s0(s0
                
                , rn):
    """Derive M0 from measured S0 and fixed RN: M0_true = sqrt(S0² - RN²).
    For value_norm, returns the normalized amplitude M0_true / S0_raw.
    When RN_FIXED is set this replaces M0 as a free parameter.
    """
    m0_true = np.sqrt(max(float(s0_raw)**2 - float(rn)**2, 0.0))
    if Y_COLUMN == "value_norm":
        return m0_true / float(s0_raw) if float(s0_raw) > 0 else 1.0
    return m0_true


def _rn_key(c):
    """Key for RN grouping based on RN_GLOBAL scope."""
    if RN_GLOBAL == "td":
        return (c["subj"], c["roi"], c["direction"], c["td"])
    return (c["subj"], c["roi"], c["direction"], c["td"], c["N"])


def _unpack(params, td=None, subj=None, s0=None):
    """Extract (M0, tc, RN) from the optimizer parameter vector (per-curve fit).
    When RN_FIXED is set and s0 is provided, M0 is derived rather than fitted.
    """
    idx = 0
    rn_val = _resolve_rn(subj, td)
    if M0_FIXED is not None:
        M0 = float(M0_FIXED)
    elif rn_val is not None and s0 is not None:
        M0 = _m0_from_s0(s0, rn_val)
    else:
        M0 = params[idx]; idx += 1
    if TC_FIXED is None:
        tc = np.exp(params[idx]); idx += 1
    else:
        tc = float(TC_FIXED)
    if rn_val is None and RN_GLOBAL is None:
        RN = params[idx]
    elif rn_val is not None:
        RN = rn_val
    else:
        RN = 0.0
    return M0, tc, RN


def _free_param_names():
    """Names of the fitted optimizer parameters, in optimizer-vector order."""
    names = []
    if M0_FIXED is None and RN_FIXED is None:
        names.append("M0")
    if TC_FIXED is None:
        names.append("tc_ms")
    if RN_FIXED is None and RN_GLOBAL is None:
        names.append("RN")
    return names


def _fit_param_errors(result, M0, tc, RN):
    """Approximate 1-sigma parameter errors from the least-squares Jacobian."""
    errs = {"M0_err": np.nan, "tc_ms_err": np.nan, "RN_err": np.nan}
    n_obs = result.fun.size
    n_params = result.x.size
    dof = n_obs - n_params
    if dof <= 0 or n_params == 0:
        return errs
    try:
        cov = np.linalg.pinv(result.jac.T @ result.jac) * (2.0 * result.cost / dof)
        stderr = np.sqrt(np.maximum(np.diag(cov), 0.0))
    except np.linalg.LinAlgError:
        return errs
    names = _free_param_names()
    for name, se in zip(names, stderr):
        errs[f"{name}_err"] = se
    return errs


def fit_curve(td, N, G, y, subj=None, s0=None):
    """Fit M_ogse_rest for ONE (td, N) curve independently.
    When RN_FIXED is set and s0 is provided, M0 is derived from sqrt(S0²-RN²).
    """
    rn_val = _resolve_rn(subj, td)
    m0_derived = (M0_FIXED is None and rn_val is not None and s0 is not None)

    def residuals(params):
        M0, tc, RN = _unpack(params, td=td, subj=subj, s0=s0)
        with np.errstate(over="ignore", invalid="ignore"):
            sig = M_ogse_rest(td, G, N, td / N, tc, M0, D0_FIXED)
            y_hat = np.sqrt(sig**2 + RN**2) if RN != 0.0 else sig
        out = y_hat - y
        return np.where(np.isfinite(out), out, 1e6)

    M0_init = float(y.max()) * M0_INIT_FRACTION
    tc_log_init = np.log(TC_INIT)
    tc_log_lower = np.log(TC_BOUNDS[0])
    tc_log_upper = np.log(TC_BOUNDS[1])
    x0 = []; lower = []; upper = []
    if M0_FIXED is None and not m0_derived:
        x0 += [M0_init]; lower += [M0_BOUNDS[0]]; upper += [M0_BOUNDS[1]]
    if TC_FIXED is None:
        x0 += [tc_log_init]; lower += [tc_log_lower]; upper += [tc_log_upper]
    if rn_val is None and RN_GLOBAL is None:
        x0 += [RN_INIT]; lower += [RN_BOUNDS[0]]; upper += [RN_BOUNDS[1]]

    if not x0:
        fun = residuals(np.array([]))
        return type("FixedResult", (), {
            "x": np.array([]),
            "fun": fun,
            "jac": np.empty((fun.size, 0)),
            "cost": 0.5 * float(np.sum(fun ** 2)),
            "success": True,
        })()

    return least_squares(residuals, x0, bounds=(lower, upper), method="trf", max_nfev=10000)


def fit_td_group(td, curves, subj=None):
    """
    Joint fit for all N curves at one (subj, roi, dir, td) with shared RN.

    Shared across N: RN (when RN_FIXED is None and RN_GLOBAL == 'td').
    Independent per N: M0 (derived from S0 if RN fixed), tc.
    Each curve dict must contain 'S0' (raw signal at G≈0).
    Returns: (result, unpack_fn) where unpack_fn(params) → (rn, m0s, tcs).
    """
    rn_fixed_val = _resolve_rn(subj, td)
    m0_derived = (M0_FIXED is None and rn_fixed_val is not None)
    tc_log_init  = np.log(TC_INIT)
    tc_log_lower = np.log(TC_BOUNDS[0])
    tc_log_upper = np.log(TC_BOUNDS[1])

    def _unpack_td(params):
        idx = 0
        if rn_fixed_val is None:
            rn = float(params[idx]); idx += 1
        else:
            rn = rn_fixed_val
        m0s = {}; tcs = {}
        for c in curves:
            if m0_derived:
                m0s[c["N"]] = _m0_from_s0(c["S0"], rn)
            elif M0_FIXED is None:
                m0s[c["N"]] = float(params[idx]); idx += 1
            else:
                m0s[c["N"]] = float(M0_FIXED)
            if TC_FIXED is None:
                tcs[c["N"]] = float(np.exp(params[idx])); idx += 1
            else:
                tcs[c["N"]] = float(TC_FIXED)
        return rn, m0s, tcs

    def residuals(params):
        rn, m0s, tcs = _unpack_td(params)
        res = []
        for c in curves:
            M0, tc = m0s[c["N"]], tcs[c["N"]]
            with np.errstate(over="ignore", invalid="ignore"):
                sig = M_ogse_rest(td, c["G"], c["N"], td / c["N"], tc, M0, D0_FIXED)
                y_hat = np.sqrt(sig**2 + rn**2) if rn != 0.0 else sig
            out = y_hat - c["y"]
            res.append(np.where(np.isfinite(out), out, 1e6))
        return np.concatenate(res)

    x0 = []; lower = []; upper = []
    if rn_fixed_val is None:
        x0 += [RN_INIT]; lower += [RN_BOUNDS[0]]; upper += [RN_BOUNDS[1]]
    for c in curves:
        if M0_FIXED is None and not m0_derived:
            x0 += [float(c["y"].max()) * M0_INIT_FRACTION]; lower += [M0_BOUNDS[0]]; upper += [M0_BOUNDS[1]]
        if TC_FIXED is None:
            x0 += [tc_log_init]; lower += [tc_log_lower]; upper += [tc_log_upper]

    if not x0:
        fun = residuals(np.array([]))
        result = type("FixedResult", (), {
            "x": np.array([]),
            "fun": fun,
            "jac": np.empty((fun.size, 0)),
            "cost": 0.5 * float(np.sum(fun**2)),
            "success": True,
        })()
        return result, _unpack_td

    result = least_squares(residuals, x0, bounds=(lower, upper), method="trf", max_nfev=10000)
    return result, _unpack_td


def fit_group_global_tc(group_df):
    """
    Joint fit with one tc shared across ALL curves in group_df.

    RN scope is controlled by RN_GLOBAL:
        "td"  → one RN per (subj, roi, dir, td), shared across N
        None  → one RN per curve
    If RN_FIXED is not None, RN is pinned and M0 is derived from sqrt(S0²-RN²).

    Returns: result, curves, tc, tc_err, M0s, rn_vals, rn_errs, rn_keys_ordered
    """
    curves = []
    for (subj, roi, direction), dir_grp in group_df.groupby(["subj", "roi", "direction"]):
        tds = sorted(float(t) for t in dir_grp.td_ms.unique())
        for td in tds:
            sub = dir_grp[np.isclose(dir_grp.td_ms.astype(float), td)]
            for N in N_LIST:
                s = sub[sub.N == N].sort_values("G_fit")
                if s.empty:
                    continue
                s0_raw = float(s.loc[s.G_fit.abs() == s.G_fit.abs().min(), "y_raw"].iloc[0])
                curves.append(dict(
                    subj=subj, roi=roi, direction=direction,
                    td=td, N=int(N),
                    G=s.G_fit.values, y=s.y_fit.values, S0=s0_raw,
                ))

    rn_keys_ordered = list(dict.fromkeys(_rn_key(c) for c in curves))
    tc_log_init  = np.log(TC_INIT)
    tc_log_lower = np.log(TC_BOUNDS[0])
    tc_log_upper = np.log(TC_BOUNDS[1])

    def unpack(params):
        idx = 0
        tc = float(np.exp(params[idx])) if TC_FIXED is None else float(TC_FIXED)
        if TC_FIXED is None: idx += 1

        rn_vals = {}
        if RN_FIXED is None:
            for key in rn_keys_ordered:
                rn_vals[key] = float(params[idx]); idx += 1
        else:
            for key in rn_keys_ordered:
                rn_vals[key] = _resolve_rn(key[0], key[3])

        M0s = {}
        for c in curves:
            key = (c["subj"], c["roi"], c["direction"], c["td"], c["N"])
            if M0_FIXED is not None:
                M0s[key] = float(M0_FIXED)
            elif RN_FIXED is not None:
                M0s[key] = _m0_from_s0(c["S0"], rn_vals[_rn_key(c)])
            else:
                M0s[key] = float(params[idx]); idx += 1
        return tc, rn_vals, M0s

    def residuals(params):
        tc, rn_vals, M0s = unpack(params)
        res = []
        for c in curves:
            M0 = M0s[(c["subj"], c["roi"], c["direction"], c["td"], c["N"])]
            rn = rn_vals[_rn_key(c)]
            with np.errstate(over="ignore", invalid="ignore"):
                sig = M_ogse_rest(c["td"], c["G"], c["N"], c["td"] / c["N"], tc, M0, D0_FIXED)
                y_hat = np.sqrt(sig**2 + rn**2) if rn != 0.0 else sig
            out = y_hat - c["y"]
            res.append(np.where(np.isfinite(out), out, 1e6))
        return np.concatenate(res)

    x0 = []; lower = []; upper = []
    if TC_FIXED is None:
        x0 += [tc_log_init]; lower += [tc_log_lower]; upper += [tc_log_upper]
    if RN_FIXED is None:
        for _ in rn_keys_ordered:
            x0 += [RN_INIT]; lower += [RN_BOUNDS[0]]; upper += [RN_BOUNDS[1]]
    for c in curves:
        if M0_FIXED is None and RN_FIXED is None:
            x0 += [float(c["y"].max()) * M0_INIT_FRACTION]; lower += [M0_BOUNDS[0]]; upper += [M0_BOUNDS[1]]

    result = least_squares(residuals, x0, bounds=(lower, upper), method="trf", max_nfev=10000)
    tc, rn_vals, M0s = unpack(result.x)

    tc_err = np.nan
    rn_errs = {key: np.nan for key in rn_keys_ordered}
    n_obs = result.fun.size
    dof = n_obs - result.x.size
    if dof > 0 and result.x.size > 0:
        try:
            cov = np.linalg.pinv(result.jac.T @ result.jac) * (2.0 * result.cost / dof)
            stderr = np.sqrt(np.maximum(np.diag(cov), 0.0))
            err_idx = 0
            if TC_FIXED is None:
                tc_err = float(stderr[err_idx]); err_idx += 1
            if RN_FIXED is None:
                for key in rn_keys_ordered:
                    rn_errs[key] = float(stderr[err_idx]); err_idx += 1
        except np.linalg.LinAlgError:
            pass

    return result, curves, tc, tc_err, M0s, rn_vals, rn_errs, rn_keys_ordered


_TC_SCOPE_COLS = {
    "direction": ["subj", "roi", "direction"],
    "roi":       ["subj", "roi"],
    "subj":      ["subj"],
    "all":       [],
}

# %%
rows      = []
fit_store = {}

if TC_GLOBAL is None:
    for (subj, roi, direction), grp in data.groupby(["subj", "roi", "direction"]):
        tds = sorted(float(t) for t in grp.td_ms.unique())
        fit_store[(subj, roi, direction)] = {"tds": tds, "fits": {td: {} for td in tds}}

        if RN_GLOBAL == "td" and RN_FIXED is None:
            # Shared RN per (subj, roi, dir, td); per-N M0 and tc
            for td in tds:
                sub = grp[np.isclose(grp.td_ms.astype(float), td)]
                td_curves = []
                for N in N_LIST:
                    s = sub[sub.N == N].sort_values("G_fit")
                    if s.empty:
                        continue
                    s0_raw = float(s.loc[s.G_fit.abs() == s.G_fit.abs().min(), "y_raw"].iloc[0])
                    td_curves.append(dict(N=int(N), G=s.G_fit.values, y=s.y_fit.values, S0=s0_raw))
                if not td_curves:
                    continue

                result, _unpack_td = fit_td_group(td, td_curves, subj=subj)
                rn, m0s, tcs = _unpack_td(result.x)

                rn_err = np.nan
                tc_errs = {c["N"]: np.nan for c in td_curves}
                m0_errs = {c["N"]: np.nan for c in td_curves}
                n_obs = result.fun.size; n_params = result.x.size; dof = n_obs - n_params
                if dof > 0 and n_params > 0:
                    try:
                        cov = np.linalg.pinv(result.jac.T @ result.jac) * (2.0 * result.cost / dof)
                        stderr = np.sqrt(np.maximum(np.diag(cov), 0.0))
                        err_idx = 0
                        if RN_FIXED is None:
                            rn_err = float(stderr[err_idx]); err_idx += 1
                        for c in td_curves:
                            if M0_FIXED is None:
                                m0_errs[c["N"]] = float(stderr[err_idx]); err_idx += 1
                            if TC_FIXED is None:
                                tc_errs[c["N"]] = float(stderr[err_idx]); err_idx += 1
                    except np.linalg.LinAlgError:
                        pass

                print(
                    f"{subj:6s}  {roi:25s}  {direction}  td={td:5.0f} ms  "
                    f"RN={rn:.4f}  cost={result.cost:.3e}"
                )
                for c in td_curves:
                    N = c["N"]; M0 = m0s[N]; tc = tcs[N]
                    fit_store[(subj, roi, direction)]["fits"][td][N] = dict(
                        G=c["G"], y=c["y"], M0=M0, tc_ms=tc, RN=rn, S0=c["S0"]
                    )
                    rows.append(dict(
                        subj=subj, roi=roi, direction=direction,
                        td_ms=td, N=N,
                        M0=M0, tc_ms=tc, D0_m2ms=D0_FIXED, RN=rn,
                        M0_err=m0_errs[N], tc_ms_err=tc_errs[N], RN_err=rn_err,
                        model_name=MODEL_NAME,
                        g_column=G_COLUMN, g_correction_column=G_CORRECTION_COLUMN, y_column=Y_COLUMN,
                        cost=float(result.cost), success=bool(result.success),
                    ))
        else:
            # Per-curve fits (also covers RN_GLOBAL=="td" with fixed RN: M0 derived per curve)
            for td in tds:
                sub = grp[np.isclose(grp.td_ms.astype(float), td)]
                for N in N_LIST:
                    s = sub[sub.N == N].sort_values("G_fit")
                    if s.empty:
                        continue
                    G, y = s.G_fit.values, s.y_fit.values
                    s0_raw = float(s.loc[s.G_fit.abs() == s.G_fit.abs().min(), "y_raw"].iloc[0])
                    result = fit_curve(td, N, G, y, subj=subj, s0=s0_raw)
                    M0, tc, RN = _unpack(result.x, td=td, subj=subj, s0=s0_raw)
                    param_errs = _fit_param_errors(result, M0, tc, RN)
                    print(
                        f"{subj:6s}  {roi:25s}  {direction}  td={td:5.0f} ms  N={N}  "
                        f"M0={M0:.4f}  tc={tc:.3f} ms  RN={RN:.4f}  cost={result.cost:.3e}"
                    )
                    fit_store[(subj, roi, direction)]["fits"][td][N] = dict(
                        G=G, y=y, M0=M0, tc_ms=tc, RN=RN, S0=s0_raw
                    )
                    rows.append(dict(
                        subj=subj, roi=roi, direction=direction,
                        td_ms=td, N=N,
                        M0=M0, tc_ms=tc, D0_m2ms=D0_FIXED, RN=RN,
                        **param_errs,
                        model_name=MODEL_NAME,
                        g_column=G_COLUMN, g_correction_column=G_CORRECTION_COLUMN, y_column=Y_COLUMN,
                        cost=float(result.cost), success=bool(result.success),
                    ))

else:
    scope_cols = _TC_SCOPE_COLS[TC_GLOBAL]
    groups = data.groupby(scope_cols) if scope_cols else [("all", data)]

    for group_key, group_df in groups:
        result, curves, tc_global, tc_err, M0s, rn_vals, rn_errs, rn_keys_ordered = fit_group_global_tc(group_df)

        key_str = group_key if isinstance(group_key, str) else (
            "  ".join(str(k) for k in group_key) if isinstance(group_key, tuple) else str(group_key)
        )
        print(f"[{key_str}]  tc={tc_global:.3f} ms  cost={result.cost:.3e}")

        for (subj, roi, direction), sub_grp in group_df.groupby(["subj", "roi", "direction"]):
            if (subj, roi, direction) not in fit_store:
                tds_srd = sorted(float(t) for t in sub_grp.td_ms.unique())
                fit_store[(subj, roi, direction)] = {"tds": tds_srd, "fits": {t: {} for t in tds_srd}}

        for c in curves:
            subj, roi, direction, td, N = c["subj"], c["roi"], c["direction"], c["td"], c["N"]
            M0  = M0s[(subj, roi, direction, td, N)]
            rn  = rn_vals[_rn_key(c)]
            rn_err = rn_errs.get(_rn_key(c), np.nan)
            fit_store[(subj, roi, direction)]["fits"][td][N] = dict(
                G=c["G"], y=c["y"], M0=M0, tc_ms=tc_global, RN=rn, S0=c["S0"]
            )
            rows.append(dict(
                subj=subj, roi=roi, direction=direction,
                td_ms=td, N=N,
                M0=M0, tc_ms=tc_global, D0_m2ms=D0_FIXED, RN=rn,
                M0_err=np.nan, tc_ms_err=tc_err, RN_err=rn_err,
                model_name=MODEL_NAME,
                g_column=G_COLUMN, g_correction_column=G_CORRECTION_COLUMN, y_column=Y_COLUMN,
                cost=float(result.cost), success=bool(result.success),
            ))
# Out:
# BRAIN   AntCC                      long  td=   76 ms  N=4  M0=245.4871  tc=7.569 ms  RN=37.0000  cost=7.122e+01
# BRAIN   AntCC                      long  td=   76 ms  N=8  M0=276.6168  tc=3.917 ms  RN=37.0000  cost=4.525e+01
# BRAIN   AntCC                      long  td=   90 ms  N=4  M0=247.8475  tc=11.687 ms  RN=34.0000  cost=2.837e+01
# BRAIN   AntCC                      long  td=   90 ms  N=8  M0=245.0788  tc=5.200 ms  RN=34.0000  cost=7.052e+01
# BRAIN   AntCC                      long  td=  120 ms  N=4  M0=183.1295  tc=11.807 ms  RN=36.0000  cost=1.489e+01
# BRAIN   AntCC                      long  td=  120 ms  N=8  M0=177.8441  tc=7.068 ms  RN=36.0000  cost=4.882e+01
# BRAIN   AntCC                      long  td=  143 ms  N=4  M0=192.9269  tc=33.108 ms  RN=36.0000  cost=9.799e+01
# BRAIN   AntCC                      long  td=  143 ms  N=8  M0=158.4544  tc=7.500 ms  RN=36.0000  cost=8.578e+01
# BRAIN   AntCC                      long  td=  210 ms  N=4  M0=137.0295  tc=76.795 ms  RN=37.0000  cost=4.189e+01
# BRAIN   AntCC                      long  td=  210 ms  N=8  M0=140.0158  tc=19.378 ms  RN=37.0000  cost=8.776e+00
# BRAIN   AntCC                      tra  td=   76 ms  N=4  M0=245.4871  tc=4.561 ms  RN=37.0000  cost=3.108e+01
# BRAIN   AntCC                      tra  td=   76 ms  N=8  M0=276.6168  tc=3.234 ms  RN=37.0000  cost=2.900e+01
# BRAIN   AntCC                      tra  td=   90 ms  N=4  M0=247.8475  tc=5.658 ms  RN=34.0000  cost=6.698e+02
# BRAIN   AntCC                      tra  td=   90 ms  N=8  M0=245.0788  tc=3.806 ms  RN=34.0000  cost=3.418e+01
# BRAIN   AntCC                      tra  td=  120 ms  N=4  M0=183.1295  tc=6.614 ms  RN=36.0000  cost=6.541e+02
# BRAIN   AntCC                      tra  td=  120 ms  N=8  M0=177.8441  tc=4.355 ms  RN=36.0000  cost=6.354e+01
# BRAIN   AntCC                      tra  td=  143 ms  N=4  M0=192.9269  tc=13.067 ms  RN=36.0000  cost=1.175e+03
# BRAIN   AntCC                      tra  td=  143 ms  N=8  M0=158.4544  tc=4.655 ms  RN=36.0000  cost=2.432e+02
# BRAIN   AntCC                      tra  td=  210 ms  N=4  M0=137.0295  tc=83.889 ms  RN=37.0000  cost=1.281e+02
# BRAIN   AntCC                      tra  td=  210 ms  N=8  M0=140.0158  tc=20.514 ms  RN=37.0000  cost=1.382e+02
# BRAIN   CentralCC                  long  td=   76 ms  N=4  M0=361.3097  tc=9.215 ms  RN=37.0000  cost=1.071e+02
# BRAIN   CentralCC                  long  td=   76 ms  N=8  M0=389.2376  tc=2.917 ms  RN=37.0000  cost=2.598e+02
# BRAIN   CentralCC                  long  td=   90 ms  N=4  M0=300.4227  tc=10.297 ms  RN=34.0000  cost=1.040e+02
# BRAIN   CentralCC                  long  td=   90 ms  N=8  M0=307.1637  tc=6.056 ms  RN=34.0000  cost=6.870e+01
# BRAIN   CentralCC                  long  td=  120 ms  N=4  M0=250.9918  tc=14.317 ms  RN=36.0000  cost=3.945e+01
# BRAIN   CentralCC                  long  td=  120 ms  N=8  M0=245.2573  tc=6.453 ms  RN=36.0000  cost=1.749e+02
# BRAIN   CentralCC                  long  td=  143 ms  N=4  M0=264.0261  tc=22.991 ms  RN=36.0000  cost=9.077e+01
# BRAIN   CentralCC                  long  td=  143 ms  N=8  M0=251.1665  tc=7.858 ms  RN=36.0000  cost=2.264e+02
# BRAIN   CentralCC                  long  td=  210 ms  N=4  M0=262.4516  tc=39.546 ms  RN=37.0000  cost=4.219e+02
# BRAIN   CentralCC                  long  td=  210 ms  N=8  M0=216.2766  tc=13.976 ms  RN=37.0000  cost=2.486e+02
# BRAIN   CentralCC                  tra  td=   76 ms  N=4  M0=361.3097  tc=7.026 ms  RN=37.0000  cost=1.315e+02
# BRAIN   CentralCC                  tra  td=   76 ms  N=8  M0=389.2376  tc=2.967 ms  RN=37.0000  cost=1.957e+02
# BRAIN   CentralCC                  tra  td=   90 ms  N=4  M0=300.4227  tc=5.611 ms  RN=34.0000  cost=4.518e+02
# BRAIN   CentralCC                  tra  td=   90 ms  N=8  M0=307.1637  tc=3.366 ms  RN=34.0000  cost=1.033e+02
# BRAIN   CentralCC                  tra  td=  120 ms  N=4  M0=250.9918  tc=6.917 ms  RN=36.0000  cost=1.109e+03
# BRAIN   CentralCC                  tra  td=  120 ms  N=8  M0=245.2573  tc=4.224 ms  RN=36.0000  cost=7.395e+01
# BRAIN   CentralCC                  tra  td=  143 ms  N=4  M0=264.0261  tc=11.574 ms  RN=36.0000  cost=2.673e+03
# BRAIN   CentralCC                  tra  td=  143 ms  N=8  M0=251.1665  tc=5.154 ms  RN=36.0000  cost=5.058e+02
# BRAIN   CentralCC                  tra  td=  210 ms  N=4  M0=262.4516  tc=31.350 ms  RN=37.0000  cost=7.763e+02
# BRAIN   CentralCC                  tra  td=  210 ms  N=8  M0=216.2766  tc=11.599 ms  RN=37.0000  cost=5.630e+02
# BRAIN   MidAntCC                   long  td=   76 ms  N=4  M0=294.0909  tc=8.253 ms  RN=37.0000  cost=5.259e+01
# BRAIN   MidAntCC                   long  td=   76 ms  N=8  M0=313.6008  tc=4.185 ms  RN=37.0000  cost=3.180e+01
# BRAIN   MidAntCC                   long  td=   90 ms  N=4  M0=286.9349  tc=10.118 ms  RN=34.0000  cost=9.021e+01
# BRAIN   MidAntCC                   long  td=   90 ms  N=8  M0=290.7277  tc=5.718 ms  RN=34.0000  cost=4.168e+01
# BRAIN   MidAntCC                   long  td=  120 ms  N=4  M0=247.1920  tc=15.241 ms  RN=36.0000  cost=4.438e+01
# BRAIN   MidAntCC                   long  td=  120 ms  N=8  M0=238.4695  tc=7.388 ms  RN=36.0000  cost=8.966e+01
# BRAIN   MidAntCC                   long  td=  143 ms  N=4  M0=240.4973  tc=25.314 ms  RN=36.0000  cost=2.311e+02
# BRAIN   MidAntCC                   long  td=  143 ms  N=8  M0=239.8498  tc=8.039 ms  RN=36.0000  cost=7.449e+01
# BRAIN   MidAntCC                   long  td=  210 ms  N=4  M0=154.4139  tc=43.966 ms  RN=37.0000  cost=4.587e+01
# BRAIN   MidAntCC                   long  td=  210 ms  N=8  M0=151.6425  tc=24.211 ms  RN=37.0000  cost=2.716e+01
# BRAIN   MidAntCC                   tra  td=   76 ms  N=4  M0=294.0909  tc=5.813 ms  RN=37.0000  cost=5.960e+01
# BRAIN   MidAntCC                   tra  td=   76 ms  N=8  M0=313.6008  tc=3.796 ms  RN=37.0000  cost=1.858e+01
# BRAIN   MidAntCC                   tra  td=   90 ms  N=4  M0=286.9349  tc=6.024 ms  RN=34.0000  cost=5.093e+02
# BRAIN   MidAntCC                   tra  td=   90 ms  N=8  M0=290.7277  tc=4.095 ms  RN=34.0000  cost=1.320e+01
# BRAIN   MidAntCC                   tra  td=  120 ms  N=4  M0=247.1920  tc=8.409 ms  RN=36.0000  cost=1.013e+03
# BRAIN   MidAntCC                   tra  td=  120 ms  N=8  M0=238.4695  tc=5.359 ms  RN=36.0000  cost=7.472e+01
# BRAIN   MidAntCC                   tra  td=  143 ms  N=4  M0=240.4973  tc=13.874 ms  RN=36.0000  cost=1.538e+03
# BRAIN   MidAntCC                   tra  td=  143 ms  N=8  M0=239.8498  tc=6.144 ms  RN=36.0000  cost=4.005e+02
# BRAIN   MidAntCC                   tra  td=  210 ms  N=4  M0=154.4139  tc=50.179 ms  RN=37.0000  cost=9.871e+01
# BRAIN   MidAntCC                   tra  td=  210 ms  N=8  M0=151.6425  tc=14.892 ms  RN=37.0000  cost=2.233e+02
# BRAIN   MidPostCC                  long  td=   76 ms  N=4  M0=330.9627  tc=10.741 ms  RN=37.0000  cost=7.844e+01
# BRAIN   MidPostCC                  long  td=   76 ms  N=8  M0=365.6452  tc=2.702 ms  RN=37.0000  cost=7.265e+02
# BRAIN   MidPostCC                  long  td=   90 ms  N=4  M0=370.5982  tc=11.575 ms  RN=34.0000  cost=2.293e+02
# BRAIN   MidPostCC                  long  td=   90 ms  N=8  M0=346.3226  tc=5.679 ms  RN=34.0000  cost=1.014e+02
# BRAIN   MidPostCC                  long  td=  120 ms  N=4  M0=354.6641  tc=18.975 ms  RN=36.0000  cost=1.408e+02
# BRAIN   MidPostCC                  long  td=  120 ms  N=8  M0=352.9145  tc=8.154 ms  RN=36.0000  cost=2.243e+02
# BRAIN   MidPostCC                  long  td=  143 ms  N=4  M0=289.9278  tc=22.792 ms  RN=36.0000  cost=5.085e+02
# BRAIN   MidPostCC                  long  td=  143 ms  N=8  M0=287.4813  tc=8.335 ms  RN=36.0000  cost=2.370e+02
# BRAIN   MidPostCC                  long  td=  210 ms  N=4  M0=263.3917  tc=80.465 ms  RN=37.0000  cost=5.213e+02
# BRAIN   MidPostCC                  long  td=  210 ms  N=8  M0=186.4305  tc=12.895 ms  RN=37.0000  cost=1.965e+02
# BRAIN   MidPostCC                  tra  td=   76 ms  N=4  M0=330.9627  tc=5.853 ms  RN=37.0000  cost=2.065e+02
# BRAIN   MidPostCC                  tra  td=   76 ms  N=8  M0=365.6452  tc=2.247 ms  RN=37.0000  cost=7.890e+02
# BRAIN   MidPostCC                  tra  td=   90 ms  N=4  M0=370.5982  tc=6.566 ms  RN=34.0000  cost=1.286e+03
# BRAIN   MidPostCC                  tra  td=   90 ms  N=8  M0=346.3226  tc=3.961 ms  RN=34.0000  cost=4.558e+01
# BRAIN   MidPostCC                  tra  td=  120 ms  N=4  M0=354.6641  tc=9.353 ms  RN=36.0000  cost=3.174e+03
# BRAIN   MidPostCC                  tra  td=  120 ms  N=8  M0=352.9145  tc=5.400 ms  RN=36.0000  cost=2.149e+02
# BRAIN   MidPostCC                  tra  td=  143 ms  N=4  M0=289.9278  tc=10.776 ms  RN=36.0000  cost=3.891e+03
# BRAIN   MidPostCC                  tra  td=  143 ms  N=8  M0=287.4813  tc=5.062 ms  RN=36.0000  cost=9.369e+02
# BRAIN   MidPostCC                  tra  td=  210 ms  N=4  M0=263.3917  tc=29.319 ms  RN=37.0000  cost=1.561e+03
# BRAIN   MidPostCC                  tra  td=  210 ms  N=8  M0=186.4305  tc=8.170 ms  RN=37.0000  cost=1.091e+03
# BRAIN   PostCC                     long  td=   76 ms  N=4  M0=274.5309  tc=10.376 ms  RN=37.0000  cost=5.738e+01
# BRAIN   PostCC                     long  td=   76 ms  N=8  M0=293.2172  tc=3.019 ms  RN=37.0000  cost=1.186e+02
# BRAIN   PostCC                     long  td=   90 ms  N=4  M0=271.3397  tc=11.538 ms  RN=34.0000  cost=5.572e+01
# BRAIN   PostCC                     long  td=   90 ms  N=8  M0=256.5558  tc=4.830 ms  RN=34.0000  cost=5.498e+01
# BRAIN   PostCC                     long  td=  120 ms  N=4  M0=220.7622  tc=18.318 ms  RN=36.0000  cost=7.096e+01
# BRAIN   PostCC                     long  td=  120 ms  N=8  M0=213.2674  tc=7.311 ms  RN=36.0000  cost=5.751e+01
# BRAIN   PostCC                     long  td=  143 ms  N=4  M0=187.9356  tc=20.296 ms  RN=36.0000  cost=8.712e+01
# BRAIN   PostCC                     long  td=  143 ms  N=8  M0=191.6123  tc=8.388 ms  RN=36.0000  cost=7.799e+01
# BRAIN   PostCC                     long  td=  210 ms  N=4  M0=207.1633  tc=49.157 ms  RN=37.0000  cost=1.003e+03
# BRAIN   PostCC                     long  td=  210 ms  N=8  M0=164.9808  tc=12.225 ms  RN=37.0000  cost=5.905e+02
# BRAIN   PostCC                     tra  td=   76 ms  N=4  M0=274.5309  tc=4.812 ms  RN=37.0000  cost=1.299e+02
# BRAIN   PostCC                     tra  td=   76 ms  N=8  M0=293.2172  tc=2.519 ms  RN=37.0000  cost=1.953e+01
# BRAIN   PostCC                     tra  td=   90 ms  N=4  M0=271.3397  tc=4.735 ms  RN=34.0000  cost=7.009e+02
# BRAIN   PostCC                     tra  td=   90 ms  N=8  M0=256.5558  tc=2.686 ms  RN=34.0000  cost=1.018e+02
# BRAIN   PostCC                     tra  td=  120 ms  N=4  M0=220.7622  tc=5.697 ms  RN=36.0000  cost=1.520e+03
# BRAIN   PostCC                     tra  td=  120 ms  N=8  M0=213.2674  tc=3.866 ms  RN=36.0000  cost=9.287e+01
# BRAIN   PostCC                     tra  td=  143 ms  N=4  M0=187.9356  tc=5.579 ms  RN=36.0000  cost=2.372e+03
# BRAIN   PostCC                     tra  td=  143 ms  N=8  M0=191.6123  tc=3.682 ms  RN=36.0000  cost=4.743e+02
# BRAIN   PostCC                     tra  td=  210 ms  N=4  M0=207.1633  tc=20.972 ms  RN=37.0000  cost=2.372e+03
# BRAIN   PostCC                     tra  td=  210 ms  N=8  M0=164.9808  tc=7.459 ms  RN=37.0000  cost=1.501e+03
# LUDG    AntCC                      long  td=   90 ms  N=4  M0=266.0440  tc=11.027 ms  RN=31.0000  cost=9.392e+01
# LUDG    AntCC                      long  td=   90 ms  N=8  M0=281.1208  tc=6.298 ms  RN=31.0000  cost=6.104e+01
# LUDG    AntCC                      long  td=  120 ms  N=4  M0=247.0256  tc=18.877 ms  RN=30.0000  cost=1.014e+02
# LUDG    AntCC                      long  td=  120 ms  N=8  M0=231.9353  tc=7.523 ms  RN=30.0000  cost=5.817e+01
# LUDG    AntCC                      long  td=  143 ms  N=4  M0=231.2435  tc=21.639 ms  RN=30.0000  cost=7.544e+01
# LUDG    AntCC                      long  td=  143 ms  N=8  M0=212.5508  tc=10.388 ms  RN=30.0000  cost=1.682e+02
# LUDG    AntCC                      long  td=  210 ms  N=4  M0=158.1276  tc=1000.000 ms  RN=31.0000  cost=5.421e+01
# LUDG    AntCC                      long  td=  210 ms  N=8  M0=156.7426  tc=21.312 ms  RN=31.0000  cost=1.152e+02
# LUDG    AntCC                      tra  td=   90 ms  N=4  M0=266.0440  tc=5.703 ms  RN=31.0000  cost=3.475e+02
# LUDG    AntCC                      tra  td=   90 ms  N=8  M0=281.1208  tc=3.718 ms  RN=31.0000  cost=5.057e+01
# LUDG    AntCC                      tra  td=  120 ms  N=4  M0=247.0256  tc=8.449 ms  RN=30.0000  cost=1.528e+03
# LUDG    AntCC                      tra  td=  120 ms  N=8  M0=231.9353  tc=4.850 ms  RN=30.0000  cost=1.522e+02
# LUDG    AntCC                      tra  td=  143 ms  N=4  M0=231.2435  tc=13.594 ms  RN=30.0000  cost=2.008e+03
# LUDG    AntCC                      tra  td=  143 ms  N=8  M0=212.5508  tc=6.097 ms  RN=30.0000  cost=6.206e+02
# LUDG    AntCC                      tra  td=  210 ms  N=4  M0=158.1276  tc=49.923 ms  RN=31.0000  cost=1.985e+02
# LUDG    AntCC                      tra  td=  210 ms  N=8  M0=156.7426  tc=21.742 ms  RN=31.0000  cost=2.409e+02
# LUDG    CentralCC                  long  td=   90 ms  N=4  M0=345.8857  tc=9.471 ms  RN=31.0000  cost=1.661e+02
# LUDG    CentralCC                  long  td=   90 ms  N=8  M0=346.3789  tc=4.604 ms  RN=31.0000  cost=1.807e+02
# LUDG    CentralCC                  long  td=  120 ms  N=4  M0=376.7333  tc=14.687 ms  RN=30.0000  cost=3.497e+02
# LUDG    CentralCC                  long  td=  120 ms  N=8  M0=366.3512  tc=6.971 ms  RN=30.0000  cost=9.840e+01
# LUDG    CentralCC                  long  td=  143 ms  N=4  M0=249.9814  tc=17.295 ms  RN=30.0000  cost=1.830e+02
# LUDG    CentralCC                  long  td=  143 ms  N=8  M0=283.6362  tc=7.756 ms  RN=30.0000  cost=2.206e+02
# LUDG    CentralCC                  long  td=  210 ms  N=4  M0=169.8506  tc=26.757 ms  RN=31.0000  cost=1.948e+02
# LUDG    CentralCC                  long  td=  210 ms  N=8  M0=176.4332  tc=12.088 ms  RN=31.0000  cost=1.525e+02
# LUDG    CentralCC                  tra  td=   90 ms  N=4  M0=345.8857  tc=5.853 ms  RN=31.0000  cost=6.074e+02
# LUDG    CentralCC                  tra  td=   90 ms  N=8  M0=346.3789  tc=3.409 ms  RN=31.0000  cost=2.402e+01
# LUDG    CentralCC                  tra  td=  120 ms  N=4  M0=376.7333  tc=9.159 ms  RN=30.0000  cost=3.222e+03
# LUDG    CentralCC                  tra  td=  120 ms  N=8  M0=366.3512  tc=5.195 ms  RN=30.0000  cost=7.128e+01
# LUDG    CentralCC                  tra  td=  143 ms  N=4  M0=249.9814  tc=8.003 ms  RN=30.0000  cost=2.605e+03
# LUDG    CentralCC                  tra  td=  143 ms  N=8  M0=283.6362  tc=5.257 ms  RN=30.0000  cost=8.275e+02
# LUDG    CentralCC                  tra  td=  210 ms  N=4  M0=169.8506  tc=16.886 ms  RN=31.0000  cost=1.044e+03
# LUDG    CentralCC                  tra  td=  210 ms  N=8  M0=176.4332  tc=8.325 ms  RN=31.0000  cost=8.623e+02
# LUDG    MidAntCC                   long  td=   90 ms  N=4  M0=289.7472  tc=8.805 ms  RN=31.0000  cost=1.835e+02
# LUDG    MidAntCC                   long  td=   90 ms  N=8  M0=321.2588  tc=4.355 ms  RN=31.0000  cost=2.811e+02
# LUDG    MidAntCC                   long  td=  120 ms  N=4  M0=270.4032  tc=16.326 ms  RN=30.0000  cost=1.587e+02
# LUDG    MidAntCC                   long  td=  120 ms  N=8  M0=270.4121  tc=6.881 ms  RN=30.0000  cost=5.410e+01
# LUDG    MidAntCC                   long  td=  143 ms  N=4  M0=243.0798  tc=14.055 ms  RN=30.0000  cost=4.474e+02
# LUDG    MidAntCC                   long  td=  143 ms  N=8  M0=225.7299  tc=7.675 ms  RN=30.0000  cost=2.856e+02
# LUDG    MidAntCC                   long  td=  210 ms  N=4  M0=167.2216  tc=169.209 ms  RN=31.0000  cost=1.417e+02
# LUDG    MidAntCC                   long  td=  210 ms  N=8  M0=161.1437  tc=17.811 ms  RN=31.0000  cost=1.651e+02
# LUDG    MidAntCC                   tra  td=   90 ms  N=4  M0=289.7472  tc=5.409 ms  RN=31.0000  cost=2.035e+02
# LUDG    MidAntCC                   tra  td=   90 ms  N=8  M0=321.2588  tc=3.606 ms  RN=31.0000  cost=7.298e+01
# LUDG    MidAntCC                   tra  td=  120 ms  N=4  M0=270.4032  tc=8.269 ms  RN=30.0000  cost=1.679e+03
# LUDG    MidAntCC                   tra  td=  120 ms  N=8  M0=270.4121  tc=4.468 ms  RN=30.0000  cost=7.150e+01
# LUDG    MidAntCC                   tra  td=  143 ms  N=4  M0=243.0798  tc=10.732 ms  RN=30.0000  cost=2.023e+03
# LUDG    MidAntCC                   tra  td=  143 ms  N=8  M0=225.7299  tc=5.311 ms  RN=30.0000  cost=4.256e+02
# LUDG    MidAntCC                   tra  td=  210 ms  N=4  M0=167.2216  tc=27.650 ms  RN=31.0000  cost=4.019e+02
# LUDG    MidAntCC                   tra  td=  210 ms  N=8  M0=161.1437  tc=11.535 ms  RN=31.0000  cost=3.707e+02
# LUDG    MidPostCC                  long  td=   90 ms  N=4  M0=434.6016  tc=12.349 ms  RN=31.0000  cost=3.702e+02
# LUDG    MidPostCC                  long  td=   90 ms  N=8  M0=447.7340  tc=6.646 ms  RN=31.0000  cost=1.171e+02
# LUDG    MidPostCC                  long  td=  120 ms  N=4  M0=486.9857  tc=16.552 ms  RN=30.0000  cost=9.670e+02
# LUDG    MidPostCC                  long  td=  120 ms  N=8  M0=481.8962  tc=9.400 ms  RN=30.0000  cost=3.762e+02
# LUDG    MidPostCC                  long  td=  143 ms  N=4  M0=402.6684  tc=27.400 ms  RN=30.0000  cost=8.676e+02
# LUDG    MidPostCC                  long  td=  143 ms  N=8  M0=420.5052  tc=10.035 ms  RN=30.0000  cost=6.436e+02
# LUDG    MidPostCC                  long  td=  210 ms  N=4  M0=313.7617  tc=102.432 ms  RN=31.0000  cost=1.188e+03
# LUDG    MidPostCC                  long  td=  210 ms  N=8  M0=315.2423  tc=14.595 ms  RN=31.0000  cost=6.672e+02
# LUDG    MidPostCC                  tra  td=   90 ms  N=4  M0=434.6016  tc=7.777 ms  RN=31.0000  cost=1.776e+03
# LUDG    MidPostCC                  tra  td=   90 ms  N=8  M0=447.7340  tc=4.868 ms  RN=31.0000  cost=5.524e+01
# LUDG    MidPostCC                  tra  td=  120 ms  N=4  M0=486.9857  tc=11.857 ms  RN=30.0000  cost=3.691e+03
# LUDG    MidPostCC                  tra  td=  120 ms  N=8  M0=481.8962  tc=7.382 ms  RN=30.0000  cost=2.746e+02
# LUDG    MidPostCC                  tra  td=  143 ms  N=4  M0=402.6684  tc=15.243 ms  RN=30.0000  cost=4.738e+03
# LUDG    MidPostCC                  tra  td=  143 ms  N=8  M0=420.5052  tc=7.880 ms  RN=30.0000  cost=1.823e+03
# LUDG    MidPostCC                  tra  td=  210 ms  N=4  M0=313.7617  tc=36.958 ms  RN=31.0000  cost=2.723e+03
# LUDG    MidPostCC                  tra  td=  210 ms  N=8  M0=315.2423  tc=14.755 ms  RN=31.0000  cost=2.245e+03
# LUDG    PostCC                     long  td=   90 ms  N=4  M0=287.1926  tc=12.150 ms  RN=31.0000  cost=1.393e+02
# LUDG    PostCC                     long  td=   90 ms  N=8  M0=285.5691  tc=4.965 ms  RN=31.0000  cost=5.233e+01
# LUDG    PostCC                     long  td=  120 ms  N=4  M0=296.2650  tc=16.103 ms  RN=30.0000  cost=3.632e+02
# LUDG    PostCC                     long  td=  120 ms  N=8  M0=307.2121  tc=7.837 ms  RN=30.0000  cost=8.746e+01
# LUDG    PostCC                     long  td=  143 ms  N=4  M0=232.0566  tc=20.994 ms  RN=30.0000  cost=6.166e+02
# LUDG    PostCC                     long  td=  143 ms  N=8  M0=235.9551  tc=7.910 ms  RN=30.0000  cost=3.347e+02
# LUDG    PostCC                     long  td=  210 ms  N=4  M0=203.9573  tc=35.655 ms  RN=31.0000  cost=1.172e+03
# LUDG    PostCC                     long  td=  210 ms  N=8  M0=195.2974  tc=12.819 ms  RN=31.0000  cost=7.165e+02
# LUDG    PostCC                     tra  td=   90 ms  N=4  M0=287.1926  tc=4.968 ms  RN=31.0000  cost=9.169e+02
# LUDG    PostCC                     tra  td=   90 ms  N=8  M0=285.5691  tc=2.948 ms  RN=31.0000  cost=8.181e+01
# LUDG    PostCC                     tra  td=  120 ms  N=4  M0=296.2650  tc=6.831 ms  RN=30.0000  cost=2.550e+03
# LUDG    PostCC                     tra  td=  120 ms  N=8  M0=307.2121  tc=4.723 ms  RN=30.0000  cost=1.136e+02
# LUDG    PostCC                     tra  td=  143 ms  N=4  M0=232.0566  tc=6.712 ms  RN=30.0000  cost=3.254e+03
# LUDG    PostCC                     tra  td=  143 ms  N=8  M0=235.9551  tc=4.330 ms  RN=30.0000  cost=9.504e+02
# LUDG    PostCC                     tra  td=  210 ms  N=4  M0=203.9573  tc=19.979 ms  RN=31.0000  cost=2.354e+03
# LUDG    PostCC                     tra  td=  210 ms  N=8  M0=195.2974  tc=8.972 ms  RN=31.0000  cost=1.678e+03
# MBBL    AntCC                      long  td=   90 ms  N=4  M0=211.8488  tc=10.718 ms  RN=35.0000  cost=2.644e+01
# MBBL    AntCC                      long  td=   90 ms  N=8  M0=214.1687  tc=4.440 ms  RN=35.0000  cost=1.540e+01
# MBBL    AntCC                      long  td=  120 ms  N=4  M0=171.7795  tc=11.903 ms  RN=31.0000  cost=6.574e+01
# MBBL    AntCC                      long  td=  120 ms  N=8  M0=170.1089  tc=5.726 ms  RN=31.0000  cost=1.538e+02
# MBBL    AntCC                      long  td=  143 ms  N=4  M0=137.3640  tc=16.072 ms  RN=31.0000  cost=2.920e+01
# MBBL    AntCC                      long  td=  143 ms  N=8  M0=154.2053  tc=7.776 ms  RN=31.0000  cost=8.288e+01
# MBBL    AntCC                      long  td=  210 ms  N=4  M0=105.9232  tc=29.795 ms  RN=35.0000  cost=2.146e+01
# MBBL    AntCC                      long  td=  210 ms  N=8  M0=110.8042  tc=15.678 ms  RN=35.0000  cost=1.236e+01
# MBBL    AntCC                      tra  td=   90 ms  N=4  M0=211.8488  tc=4.540 ms  RN=35.0000  cost=1.658e+02
# MBBL    AntCC                      tra  td=   90 ms  N=8  M0=214.1687  tc=2.555 ms  RN=35.0000  cost=1.711e+01
# MBBL    AntCC                      tra  td=  120 ms  N=4  M0=171.7795  tc=6.339 ms  RN=31.0000  cost=8.456e+02
# MBBL    AntCC                      tra  td=  120 ms  N=8  M0=170.1089  tc=3.641 ms  RN=31.0000  cost=1.284e+02
# MBBL    AntCC                      tra  td=  143 ms  N=4  M0=137.3640  tc=7.249 ms  RN=31.0000  cost=4.839e+02
# MBBL    AntCC                      tra  td=  143 ms  N=8  M0=154.2053  tc=4.779 ms  RN=31.0000  cost=3.483e+02
# MBBL    AntCC                      tra  td=  210 ms  N=4  M0=105.9232  tc=24.817 ms  RN=35.0000  cost=5.304e+01
# MBBL    AntCC                      tra  td=  210 ms  N=8  M0=110.8042  tc=11.929 ms  RN=35.0000  cost=8.399e+01
# MBBL    CentralCC                  long  td=   90 ms  N=4  M0=364.1988  tc=9.846 ms  RN=35.0000  cost=1.603e+02
# MBBL    CentralCC                  long  td=   90 ms  N=8  M0=368.1788  tc=4.916 ms  RN=35.0000  cost=7.424e+01
# MBBL    CentralCC                  long  td=  120 ms  N=4  M0=326.1468  tc=13.371 ms  RN=31.0000  cost=4.340e+02
# MBBL    CentralCC                  long  td=  120 ms  N=8  M0=338.5477  tc=7.034 ms  RN=31.0000  cost=1.475e+02
# MBBL    CentralCC                  long  td=  143 ms  N=4  M0=297.3460  tc=22.063 ms  RN=31.0000  cost=5.002e+02
# MBBL    CentralCC                  long  td=  143 ms  N=8  M0=308.2797  tc=8.150 ms  RN=31.0000  cost=3.400e+02
# MBBL    CentralCC                  long  td=  210 ms  N=4  M0=214.8073  tc=30.950 ms  RN=35.0000  cost=4.645e+02
# MBBL    CentralCC                  long  td=  210 ms  N=8  M0=232.8388  tc=16.505 ms  RN=35.0000  cost=3.552e+02
# MBBL    CentralCC                  tra  td=   90 ms  N=4  M0=364.1988  tc=6.581 ms  RN=35.0000  cost=1.022e+03
# MBBL    CentralCC                  tra  td=   90 ms  N=8  M0=368.1788  tc=3.656 ms  RN=35.0000  cost=8.433e+01
# MBBL    CentralCC                  tra  td=  120 ms  N=4  M0=326.1468  tc=8.814 ms  RN=31.0000  cost=2.158e+03
# MBBL    CentralCC                  tra  td=  120 ms  N=8  M0=338.5477  tc=5.528 ms  RN=31.0000  cost=2.789e+02
# MBBL    CentralCC                  tra  td=  143 ms  N=4  M0=297.3460  tc=10.963 ms  RN=31.0000  cost=3.331e+03
# MBBL    CentralCC                  tra  td=  143 ms  N=8  M0=308.2797  tc=6.041 ms  RN=31.0000  cost=1.010e+03
# MBBL    CentralCC                  tra  td=  210 ms  N=4  M0=214.8073  tc=22.992 ms  RN=35.0000  cost=1.576e+03
# MBBL    CentralCC                  tra  td=  210 ms  N=8  M0=232.8388  tc=11.602 ms  RN=35.0000  cost=1.285e+03
# MBBL    MidAntCC                   long  td=   90 ms  N=4  M0=364.3159  tc=10.726 ms  RN=35.0000  cost=2.192e+02
# MBBL    MidAntCC                   long  td=   90 ms  N=8  M0=356.0169  tc=4.517 ms  RN=35.0000  cost=4.222e+01
# MBBL    MidAntCC                   long  td=  120 ms  N=4  M0=283.6265  tc=13.045 ms  RN=31.0000  cost=1.812e+02
# MBBL    MidAntCC                   long  td=  120 ms  N=8  M0=280.3471  tc=6.818 ms  RN=31.0000  cost=6.132e+01
# MBBL    MidAntCC                   long  td=  143 ms  N=4  M0=279.9195  tc=19.335 ms  RN=31.0000  cost=1.509e+02
# MBBL    MidAntCC                   long  td=  143 ms  N=8  M0=245.2217  tc=7.168 ms  RN=31.0000  cost=1.852e+02
# MBBL    MidAntCC                   long  td=  210 ms  N=4  M0=202.6904  tc=39.777 ms  RN=35.0000  cost=9.866e+01
# MBBL    MidAntCC                   long  td=  210 ms  N=8  M0=212.2143  tc=15.923 ms  RN=35.0000  cost=3.967e+01
# MBBL    MidAntCC                   tra  td=   90 ms  N=4  M0=364.3159  tc=7.089 ms  RN=35.0000  cost=9.181e+02
# MBBL    MidAntCC                   tra  td=   90 ms  N=8  M0=356.0169  tc=3.903 ms  RN=35.0000  cost=3.129e+01
# MBBL    MidAntCC                   tra  td=  120 ms  N=4  M0=283.6265  tc=8.503 ms  RN=31.0000  cost=1.055e+03
# MBBL    MidAntCC                   tra  td=  120 ms  N=8  M0=280.3471  tc=5.029 ms  RN=31.0000  cost=6.399e+01
# MBBL    MidAntCC                   tra  td=  143 ms  N=4  M0=279.9195  tc=12.851 ms  RN=31.0000  cost=1.736e+03
# MBBL    MidAntCC                   tra  td=  143 ms  N=8  M0=245.2217  tc=5.843 ms  RN=31.0000  cost=7.119e+02
# MBBL    MidAntCC                   tra  td=  210 ms  N=4  M0=202.6904  tc=26.498 ms  RN=35.0000  cost=2.717e+02
# MBBL    MidAntCC                   tra  td=  210 ms  N=8  M0=212.2143  tc=12.681 ms  RN=35.0000  cost=3.162e+02
# MBBL    MidPostCC                  long  td=   90 ms  N=4  M0=417.3274  tc=11.905 ms  RN=35.0000  cost=3.351e+02
# MBBL    MidPostCC                  long  td=   90 ms  N=8  M0=406.6352  tc=4.602 ms  RN=35.0000  cost=2.947e+02
# MBBL    MidPostCC                  long  td=  120 ms  N=4  M0=396.1803  tc=21.251 ms  RN=31.0000  cost=1.808e+03
# MBBL    MidPostCC                  long  td=  120 ms  N=8  M0=381.2620  tc=7.755 ms  RN=31.0000  cost=1.549e+02
# MBBL    MidPostCC                  long  td=  143 ms  N=4  M0=344.3424  tc=21.236 ms  RN=31.0000  cost=1.097e+03
# MBBL    MidPostCC                  long  td=  143 ms  N=8  M0=347.5189  tc=10.158 ms  RN=31.0000  cost=8.057e+02
# MBBL    MidPostCC                  long  td=  210 ms  N=4  M0=291.4959  tc=78.822 ms  RN=35.0000  cost=1.498e+03
# MBBL    MidPostCC                  long  td=  210 ms  N=8  M0=275.4202  tc=19.298 ms  RN=35.0000  cost=6.830e+02
# MBBL    MidPostCC                  tra  td=   90 ms  N=4  M0=417.3274  tc=8.150 ms  RN=35.0000  cost=1.252e+03
# MBBL    MidPostCC                  tra  td=   90 ms  N=8  M0=406.6352  tc=3.973 ms  RN=35.0000  cost=1.351e+02
# MBBL    MidPostCC                  tra  td=  120 ms  N=4  M0=396.1803  tc=12.817 ms  RN=31.0000  cost=3.859e+03
# MBBL    MidPostCC                  tra  td=  120 ms  N=8  M0=381.2620  tc=5.958 ms  RN=31.0000  cost=3.169e+02
# MBBL    MidPostCC                  tra  td=  143 ms  N=4  M0=344.3424  tc=13.022 ms  RN=31.0000  cost=2.508e+03
# MBBL    MidPostCC                  tra  td=  143 ms  N=8  M0=347.5189  tc=7.222 ms  RN=31.0000  cost=9.518e+02
# MBBL    MidPostCC                  tra  td=  210 ms  N=4  M0=291.4959  tc=31.140 ms  RN=35.0000  cost=1.723e+03
# MBBL    MidPostCC                  tra  td=  210 ms  N=8  M0=275.4202  tc=12.987 ms  RN=35.0000  cost=1.579e+03
# MBBL    PostCC                     long  td=   90 ms  N=4  M0=291.9471  tc=14.166 ms  RN=35.0000  cost=8.308e+01
# MBBL    PostCC                     long  td=   90 ms  N=8  M0=282.6674  tc=4.593 ms  RN=35.0000  cost=1.036e+02
# MBBL    PostCC                     long  td=  120 ms  N=4  M0=230.9628  tc=16.103 ms  RN=31.0000  cost=2.939e+02
# MBBL    PostCC                     long  td=  120 ms  N=8  M0=246.5582  tc=6.966 ms  RN=31.0000  cost=1.486e+02
# MBBL    PostCC                     long  td=  143 ms  N=4  M0=212.3128  tc=19.225 ms  RN=31.0000  cost=5.210e+02
# MBBL    PostCC                     long  td=  143 ms  N=8  M0=189.6888  tc=7.349 ms  RN=31.0000  cost=2.149e+02
# MBBL    PostCC                     long  td=  210 ms  N=4  M0=152.4402  tc=27.051 ms  RN=35.0000  cost=9.890e+02
# MBBL    PostCC                     long  td=  210 ms  N=8  M0=150.7265  tc=12.377 ms  RN=35.0000  cost=7.051e+02
# MBBL    PostCC                     tra  td=   90 ms  N=4  M0=291.9471  tc=5.271 ms  RN=35.0000  cost=8.449e+02
# MBBL    PostCC                     tra  td=   90 ms  N=8  M0=282.6674  tc=2.821 ms  RN=35.0000  cost=7.242e+01
# MBBL    PostCC                     tra  td=  120 ms  N=4  M0=230.9628  tc=6.199 ms  RN=31.0000  cost=1.483e+03
# MBBL    PostCC                     tra  td=  120 ms  N=8  M0=246.5582  tc=4.342 ms  RN=31.0000  cost=1.016e+02
# MBBL    PostCC                     tra  td=  143 ms  N=4  M0=212.3128  tc=7.530 ms  RN=31.0000  cost=2.921e+03
# MBBL    PostCC                     tra  td=  143 ms  N=8  M0=189.6888  tc=3.979 ms  RN=31.0000  cost=4.626e+02
# MBBL    PostCC                     tra  td=  210 ms  N=4  M0=152.4402  tc=14.879 ms  RN=35.0000  cost=2.036e+03
# MBBL    PostCC                     tra  td=  210 ms  N=8  M0=150.7265  tc=7.091 ms  RN=35.0000  cost=1.419e+03

# %%
results_df = pd.DataFrame(rows)
results_df.to_excel(OUT_DIR / "fit_results.xlsx", index=False)
print(f"Saved {len(results_df)} rows to {OUT_DIR / 'fit_results.xlsx'}")
results_df
# Out:
# Saved 260 rows to ../../analysis/brains/ogse_experiments/lab/fit_rest-a1/fit_results.xlsx
#       subj     roi direction  td_ms  N          M0      tc_ms       D0_m2ms  \
# 0    BRAIN   AntCC      long   76.0  4  245.487080   7.568726  3.000000e-12
# 1    BRAIN   AntCC      long   76.0  8  276.616751   3.917055  3.000000e-12
# 2    BRAIN   AntCC      long   90.0  4  247.847465  11.686678  3.000000e-12
# 3    BRAIN   AntCC      long   90.0  8  245.078765   5.200068  3.000000e-12
# 4    BRAIN   AntCC      long  120.0  4  183.129514  11.806743  3.000000e-12
# ..     ...     ...       ...    ... ..         ...        ...           ...
# 255   MBBL  PostCC       tra  120.0  8  246.558237   4.341629  3.000000e-12
# 256   MBBL  PostCC       tra  143.4  4  212.312792   7.529533  3.000000e-12
# 257   MBBL  PostCC       tra  143.4  8  189.688781   3.979046  3.000000e-12
# 258   MBBL  PostCC       tra  210.0  4  152.440154  14.878715  3.000000e-12
# 259   MBBL  PostCC       tra  210.0  8  150.726490   7.090881  3.000000e-12
#
#        RN  M0_err  tc_ms_err  RN_err model_name    g_column  \
# 0    37.0     NaN   0.032194     NaN       rest  g_thorsten
# 1    37.0     NaN   0.053367     NaN       rest  g_thorsten
# 2    34.0     NaN   0.022089     NaN       rest  g_thorsten
# 3    34.0     NaN   0.045396     NaN       rest  g_thorsten
# 4    36.0     NaN   0.018006     NaN       rest  g_thorsten
# ..    ...     ...        ...     ...        ...         ...
# 255  31.0     NaN   0.026761     NaN       rest  g_thorsten
# 256  31.0     NaN   0.120682     NaN       rest  g_thorsten
# 257  31.0     NaN   0.051516     NaN       rest  g_thorsten
# 258  35.0     NaN   0.261361     NaN       rest  g_thorsten
# 259  35.0     NaN   0.164785     NaN       rest  g_thorsten
#
#         g_correction_column y_column         cost  success
# 0    grad_correction_factor    value    71.223969     True
# 1    grad_correction_factor    value    45.249005     True
# 2    grad_correction_factor    value    28.368963     True
# 3    grad_correction_factor    value    70.518675     True
# 4    grad_correction_factor    value    14.890537     True
# ..                      ...      ...          ...      ...
# 255  grad_correction_factor    value   101.563938     True
# 256  grad_correction_factor    value  2921.122109     True
# 257  grad_correction_factor    value   462.598266     True
# 258  grad_correction_factor    value  2036.394441     True
# 259  grad_correction_factor    value  1418.781939     True
#
# [260 rows x 18 columns]

# %%
G_plot = np.linspace(0, float(data.G_fit.max()), 300)
N_hi, N_lo = N_LIST[-1], N_LIST[0]

for (subj, roi, direction), store in fit_store.items():
    tds   = store["tds"]
    n_tds = len(tds)

    fig, axes_grid = plt.subplots(2, n_tds, figsize=(4 * n_tds, 7), sharey="row", squeeze=False)
    axes      = axes_grid[0]
    diff_axes = axes_grid[1]

    for ax, dax, td in zip(axes, diff_axes, tds):
        fits_td = store["fits"][td]
        title_lines = [f"td = {td:.1f} ms"]
        y_hat_per_N = {}
        for N, color in zip(N_LIST, ["C0", "C1", "C2", "C3"]):
            fit = fits_td.get(N)
            if fit is None:
                continue
            ax.scatter(fit["G"], fit["y"], color=color, s=20, zorder=3, label=f"N={N} data")
            rn = fit.get("RN", 0.0)
            with np.errstate(over="ignore", invalid="ignore"):
                sig = M_ogse_rest(td, G_plot, N, td / N, fit["tc_ms"], fit["M0"], D0_FIXED)
                y_hat = np.sqrt(sig**2 + rn**2) if rn != 0.0 else sig
            y_hat_per_N[N] = y_hat
            ax.plot(G_plot, y_hat, color=color, label=f"N={N} fit")
            title_lines.append(f"tc(N={N}) = {fit['tc_ms']:.3f} ms  RN={rn:.3f}")
        ax.set_title("\n".join(title_lines), fontsize=7)
        ax.set_xlabel(G_LABEL)
        ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)
        if N_hi in y_hat_per_N and N_lo in y_hat_per_N:
            dax.plot(G_plot, y_hat_per_N[N_hi] - y_hat_per_N[N_lo], color="k")
            dax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
        dax.set_title(f"td = {td:.1f} ms  (N={N_hi} − N={N_lo})", fontsize=8)
        dax.set_xlabel(G_LABEL)
        dax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
        dax.set_axisbelow(True)

    axes[0].set_ylabel(Y_LABEL)
    diff_axes[0].set_ylabel(f"ΔS  (N={N_hi} − N={N_lo})")
    axes[0].legend(fontsize=6)
    fig.suptitle(f"{subj}  |  {roi}  |  {direction}", fontsize=9)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"fit_{subj}_{roi}_{direction}.png", dpi=120)
    plt.close(fig)

print("Fit plots saved.")
# Out:
# Fit plots saved.

# %%
rois     = sorted(results_df.roi.unique())
subjects = sorted(results_df.subj.unique())
roi_colors = _roi_color_map(rois)
_N_ls        = ["-", "--", "-.", ":"]
N_linestyles = {N: ls for N, ls in zip(N_LIST, _N_ls)}

for direction in DIRECTIONS:
    sub = results_df[results_df.direction == direction]
    fig, axes = plt.subplots(1, len(rois), figsize=(4 * len(rois), 4), sharey=True)
    axes = np.atleast_1d(axes)

    for ax, roi in zip(axes, rois):
        base_color = roi_colors[roi]
        cmap = mcolors.LinearSegmentedColormap.from_list("", ["#cccccc", base_color])
        for i, subj in enumerate(subjects):
            shade = cmap(0.3 + 0.7 * i / max(1, len(subjects) - 1))
            marker = DEFAULT_BRAIN_MARKERS[i % len(DEFAULT_BRAIN_MARKERS)]
            for N in N_LIST:
                g = (
                    sub[(sub.roi == roi) & (sub.subj == subj) & (sub.N == N)]
                    .drop_duplicates("td_ms")
                    .sort_values("td_ms")
                )
                if g.empty:
                    continue
                label = subj if N == N_LIST[0] else None
                ax.scatter(g.td_ms, g.tc_ms, color=shade, marker=marker, s=60, zorder=3)
                ax.plot(g.td_ms, g.tc_ms, color=shade, linewidth=0.8,
                        linestyle=N_linestyles[N], label=label)
        ax.set_title(roi, fontsize=9)
        ax.set_xlabel("td [ms]")
        ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)

    axes[0].set_ylabel("tc [ms]")
    handles, labels = axes[0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels, fontsize=7, loc="upper right", ncol=1)
    n_handles = [mlines.Line2D([], [], color="gray", linestyle=N_linestyles[N], label=f"N={N}") for N in N_LIST]
    axes[-1].legend(handles=n_handles, fontsize=7, loc="lower right")
    fig.suptitle(f"tc vs td — direction: {direction}", fontsize=10)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"tc_vs_td_{direction}.png", dpi=120)
    plt.show()

# %%
for (subj, roi, direction), store in fit_store.items():
    tds   = store["tds"]
    n_tds = len(tds)

    fig, axes_grid = plt.subplots(2, n_tds, figsize=(4 * n_tds, 7), sharey="row", squeeze=False)
    axes      = axes_grid[0]
    diff_axes = axes_grid[1]

    for ax, dax, td in zip(axes, diff_axes, tds):
        fits_td = store["fits"][td]
        y_hat_per_N = {}
        for N, color in zip(N_LIST, ["C0", "C1", "C2", "C3"]):
            fit = fits_td.get(N)
            if fit is None:
                continue
            M0 = fit["M0"] if fit["M0"] != 0.0 else 1.0
            ax.scatter(fit["G"], fit["y"] / M0, color=color, s=20, zorder=3, label=f"N={N} data")
            with np.errstate(over="ignore", invalid="ignore"):
                sig_norm = M_ogse_rest(td, G_plot, N, td / N, fit["tc_ms"], 1.0, D0_FIXED)
            y_hat_per_N[N] = sig_norm
            ax.plot(G_plot, sig_norm, color=color, label=f"N={N} model")
        ax.set_title(f"td = {td:.1f} ms", fontsize=8)
        ax.set_xlabel(G_LABEL)
        ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)
        if N_hi in y_hat_per_N and N_lo in y_hat_per_N:
            dax.plot(G_plot, y_hat_per_N[N_hi] - y_hat_per_N[N_lo], color="k")
            dax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
        dax.set_title(f"td = {td:.1f} ms  (N={N_hi} − N={N_lo})", fontsize=8)
        dax.set_xlabel(G_LABEL)
        dax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
        dax.set_axisbelow(True)

    axes[0].set_ylabel(f"{Y_COLUMN} / M0 [a.u.]")
    diff_axes[0].set_ylabel(f"ΔS  (N={N_hi} − N={N_lo})")
    axes[0].legend(fontsize=6)
    fig.suptitle(f"{subj}  |  {roi}  |  {direction}  |  clean model (no RN)", fontsize=9)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"fit_norm_{subj}_{roi}_{direction}.png", dpi=120)
    plt.close(fig)

print("Clean model fit plots saved.")
# Out:
# Clean model fit plots saved.

# %%
subjects_plot = sorted(results_df.subj.unique())
rois_plot     = sorted(results_df.roi.unique())
Ns_plot       = sorted(results_df.N.unique())
dirs_plot     = [d for d in ["long", "tra"] if d in results_df.direction.unique()]
_N_ls_p       = ["-", "--", "-.", ":"]
N_ls          = {N: _N_ls_p[i % len(_N_ls_p)] for i, N in enumerate(Ns_plot)}

for subj in subjects_plot:
    for param, ylabel in [("tc_ms", "tc [ms]"), ("M0", "M0 [a.u.]")]:
        fig, axes = plt.subplots(
            len(rois_plot), len(dirs_plot),
            figsize=(4 * len(dirs_plot), 3 * len(rois_plot)),
            sharey=False, squeeze=False
        )
        for i_roi, roi in enumerate(rois_plot):
            for i_dir, direction in enumerate(dirs_plot):
                ax = axes[i_roi, i_dir]
                sub = results_df[
                    (results_df.subj == subj) &
                    (results_df.roi == roi) &
                    (results_df.direction == direction)
                ]
                for N in Ns_plot:
                    g = sub[sub.N == N].sort_values("td_ms")
                    if g.empty:
                        continue
                    line, = ax.plot(g.td_ms, g[param], linestyle=N_ls[N],
                                    marker="o", ms=4, linewidth=0.8, label=f"N={N}")
                    err_col = f"{param}_err"
                    if err_col in g.columns:
                        x = g.td_ms.to_numpy(dtype=float)
                        y = g[param].to_numpy(dtype=float)
                        yerr = g[err_col].to_numpy(dtype=float)
                        ok = np.isfinite(x) & np.isfinite(y) & np.isfinite(yerr)
                        if np.any(ok):
                            ax.fill_between(
                                x[ok], y[ok] - yerr[ok], y[ok] + yerr[ok],
                                color=line.get_color(), alpha=0.18, linewidth=0
                            )
                if i_roi == 0:
                    ax.set_title(direction, fontsize=9)
                if i_dir == 0:
                    ax.set_ylabel(f"{roi}\n{ylabel}", fontsize=8)
                ax.set_xlabel("td [ms]")
                ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
                ax.set_axisbelow(True)
                if i_roi == 0 and i_dir == len(dirs_plot) - 1:
                    ax.legend(fontsize=6, title="N", title_fontsize=6)
        fig.suptitle(f"{subj} — {param} vs td", fontsize=11)
        fig.tight_layout()
        fig.savefig(OUT_DIR / f"{param}_vs_td_{subj}.png", dpi=120)
        plt.close(fig)

# %%
for subj in subjects_plot:
    for param, ylabel in [("tc_ms", "tc [ms]"), ("M0", "M0 [a.u.]")]:
        fig, axes = plt.subplots(
            len(rois_plot), len(dirs_plot),
            figsize=(4 * len(dirs_plot), 3 * len(rois_plot)),
            sharey=False, squeeze=False
        )
        for i_roi, roi in enumerate(rois_plot):
            for i_dir, direction in enumerate(dirs_plot):
                ax = axes[i_roi, i_dir]
                sub = results_df[
                    (results_df.subj == subj) &
                    (results_df.roi == roi) &
                    (results_df.direction == direction)
                ]
                for N in Ns_plot:
                    g = sub[sub.N == N].sort_values("td_ms")
                    if g.empty:
                        continue
                    line, = ax.plot(g.td_ms, g[param], linestyle=N_ls[N],
                                    marker="o", ms=4, linewidth=0.8, label=f"N={N}")
                    err_col = f"{param}_err"
                    if err_col in g.columns:
                        x = g.td_ms.to_numpy(dtype=float)
                        y = g[param].to_numpy(dtype=float)
                        yerr = g[err_col].to_numpy(dtype=float)
                        lower = np.maximum(y - yerr, np.finfo(float).tiny)
                        upper = y + yerr
                        ok = np.isfinite(x) & np.isfinite(y) & np.isfinite(yerr) & (y > 0) & (upper > 0)
                        if np.any(ok):
                            ax.fill_between(
                                x[ok], lower[ok], upper[ok],
                                color=line.get_color(), alpha=0.18, linewidth=0
                            )
                ax.set_yscale("log")
                if i_roi == 0:
                    ax.set_title(direction, fontsize=9)
                if i_dir == 0:
                    ax.set_ylabel(f"{roi}\n{ylabel} (log)", fontsize=8)
                ax.set_xlabel("td [ms]")
                ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
                ax.set_axisbelow(True)
                if i_roi == 0 and i_dir == len(dirs_plot) - 1:
                    ax.legend(fontsize=6, title="N", title_fontsize=6)
        fig.suptitle(f"{subj} — {param} vs td  (log scale)", fontsize=11)
        fig.tight_layout()
        fig.savefig(OUT_DIR / f"{param}_vs_td_log_{subj}.png", dpi=120)
        plt.close(fig)

# %%
# ── Per-subject contrast figures: ROIs × directions, contrast curves per td ──
# _raw  = full fit including RN noise:  sqrt(sig² + rn²)
# _corr = clean model, no noise:        sig
td_cmap    = plt.cm.viridis
N_hi, N_lo = 8, 4
G_plot     = np.linspace(0, float(data.G_fit.max()), 300)
PEAK_GAMMA = 267.5221900   # rad / (ms · mT), proton gyromagnetic ratio

def _x_for_td(td_ms, xvar):
    if xvar == "G":
        return G_plot.copy()
    D0, gamma = float(D0_PLOT), float(PEAK_GAMMA)
    l_d = np.sqrt(D0 * float(td_ms))
    l_G = np.full_like(G_plot, np.nan)
    valid = G_plot > 0
    l_G[valid] = (D0 / (gamma * G_plot[valid])) ** (1.0 / 3.0)
    Ld  = l_d / l_G
    Lcf = 1.5 ** 0.25 / np.sqrt(Ld)
    lcf = Lcf * l_G * 1e6
    if xvar == "Ld":  return Ld
    if xvar == "Lcf": return Lcf
    if xvar == "lcf": return lcf
    raise ValueError(xvar)

X_AXES = [
    ("G",   G_LABEL),
    ("Ld",  "Lᵈ (dimensionless)"),
    ("Lcf", "Lcf (dimensionless)"),
    ("lcf", "lcf [µm]"),
]

D0_PLOT = D0_FIXED

# ── precompute contrasts ───────────────────────────────────────────────────────
raw_contrast_store  = {}   # sqrt(sig² + rn²)
corr_contrast_store = {}   # sig only

for (subj, roi, direction), store in fit_store.items():
    for td in store["tds"]:
        raw_per_N  = {}
        corr_per_N = {}
        for N in N_LIST:
            fit = store["fits"][td].get(N)
            if fit is None:
                continue
            rn = fit.get("RN", 0.0)
            with np.errstate(over="ignore", invalid="ignore"):
                sig   = M_ogse_rest(td, G_plot, N, td / N, fit["tc_ms"], fit["M0"], D0_FIXED)
                y_hat = np.sqrt(sig**2 + rn**2) if rn != 0.0 else sig
            raw_per_N[N]  = y_hat
            corr_per_N[N] = sig
        if N_hi in raw_per_N and N_lo in raw_per_N:
            raw_contrast_store[(subj, roi, direction, td)]  = raw_per_N[N_hi]  - raw_per_N[N_lo]
        if N_hi in corr_per_N and N_lo in corr_per_N:
            corr_contrast_store[(subj, roi, direction, td)] = corr_per_N[N_hi] - corr_per_N[N_lo]

# ── helper ─────────────────────────────────────────────────────────────────────
def _plot_contrast(cstore, xvar, xlabel, subj, suffix, title_tag):
    rois_subj = sorted(set(k[1] for k in cstore if k[0] == subj))
    dirs_subj = [d for d in DIRECTIONS if any(k[2] == d for k in cstore if k[0] == subj)]
    n_rois, n_dirs = len(rois_subj), len(dirs_subj)
    if n_rois == 0 or n_dirs == 0:
        return
    all_tds_subj = sorted(set(k[3] for k in cstore if k[0] == subj))
    colors_leg   = [td_cmap(i / max(1, len(all_tds_subj) - 1)) for i in range(len(all_tds_subj))]
    leg_handles  = [plt.Line2D([0], [0], color=c, linewidth=1.5) for c in colors_leg]
    leg_labels   = [f"td={td:.0f} ms" for td in all_tds_subj]
    td_color_map = {td: c for td, c in zip(all_tds_subj, colors_leg)}
    fig, axes = plt.subplots(n_rois, n_dirs, figsize=(4 * n_dirs, 3 * n_rois), squeeze=False)
    for i_roi, roi in enumerate(rois_subj):
        for i_dir, direction in enumerate(dirs_subj):
            ax = axes[i_roi, i_dir]
            tds_here = sorted(k[3] for k in cstore
                              if k[0] == subj and k[1] == roi and k[2] == direction)
            if not tds_here:
                ax.set_visible(False)
                continue
            for td in tds_here:
                ax.plot(_x_for_td(td, xvar), cstore[(subj, roi, direction, td)],
                        color=td_color_map[td], linewidth=1.2)
            ax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
            if i_roi == 0:
                ax.set_title(direction, fontsize=9)
            if i_dir == 0:
                ax.set_ylabel(f"{roi}\nΔS (N={N_hi}−N={N_lo})", fontsize=7)
            ax.set_xlabel(xlabel, fontsize=7)
            ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
            ax.set_axisbelow(True)
            ax.tick_params(labelsize=6)
    fig.suptitle(f"{subj} — contrast ΔS (N={N_hi}−N={N_lo}) vs {xvar}  [{title_tag}]", fontsize=10)
    fig.legend(leg_handles, leg_labels,
               loc="upper center", ncol=len(leg_labels), fontsize=7, frameon=False,
               bbox_to_anchor=(0.5, 1.04), bbox_transform=fig.transFigure)
    fig.tight_layout(rect=[0, 0, 1, 0.87])
    fig.savefig(OUT_DIR / f"contrast_vs_{xvar}_{subj}_{suffix}.png", dpi=120, bbox_inches="tight")
    plt.close(fig)

# ── generate _raw and _corr figures ───────────────────────────────────────────
all_subjs = sorted(set(k[0] for k in raw_contrast_store))
for xvar, xlabel in X_AXES:
    for subj in all_subjs:
        _plot_contrast(raw_contrast_store,  xvar, xlabel, subj, "raw",  "fit w/ RN")
        _plot_contrast(corr_contrast_store, xvar, xlabel, subj, "corr", "clean model")

print("Per-subject contrast figures saved (_raw and _corr).")
# Out:
# Per-subject contrast figures saved (_raw and _corr).
