# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.lines as mlines
from scipy.optimize import least_squares

sys.path.insert(0, str(Path("../../nogse_pipeline/src")))
from models.model_fitting import M_ogse_tort
from plotting.publication.tc_param_vars import _roi_color_map, DEFAULT_BRAIN_MARKERS

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════

MASTER_PATH  = Path("../../analysis/brains/ogse_experiments/master.long.parquet")
OUT_DIR      = Path("../../analysis/brains/ogse_experiments/lab/fit_ogse_free_CC-a1")
OUT_DIR.mkdir(parents=True, exist_ok=True)

DIRECTIONS  = ["tra", "long"]
N_LIST      = [4, 8]
TD_LIST     = None
#ROI_LIST
# None → All ROIS
# ["AntCC","MidAntCC","CentralCC","MidPostCC","PostCC"]
ROI_LIST    = ["AntCC","MidAntCC","CentralCC","MidPostCC","PostCC"]
G_COLUMN    = "g_thorsten"
G_CORRECTION_COLUMN = "grad_correction_factor"
Y_COLUMN    = "value"         # "value" (raw a.u.) or "value_norm" (normalized by S0)
D0_FIXED    = 3.2e-12         # m²/ms, fixed free-water diffusivity

# ── Tortuosity factor α ───────────────────────────────────────────────────────
ALPHA_FIXED  = 1.0           # None → fitted per curve; float → pinned; "master" → from master table
ALPHA_INIT   = 0.5
ALPHA_BOUNDS = (0.0, 1.0)

# ALPHA_GLOBAL: scope for a shared α fit
#   None         → per-curve (one α per td, N, direction)
#   "direction"  → one α per (subj, roi, direction), shared across td & N
#   "roi"        → one α per (subj, roi), shared across td, N & direction
#   "subj"       → one α per subject, shared across all roi, td, N & direction
#   "all"        → one α for all data
ALPHA_GLOBAL = None

ALPHA_MASTER_COL = "alpha_macro"   # master table column (used when ALPHA_FIXED = "master")

# ── Rician noise floor RN (signal units) ─────────────────────────────────────
# Signal model:  S(G) = sqrt( (S0² − RN²) · S_model(α, G)² + RN² )
# Equivalently:  M0 = sqrt(S0² − RN²)  and  S(G) = sqrt( M0² · S_model² + RN² )
# S0 is the measured signal at G ≈ 0; M0 and RN are never fitted.
#
#   None                        → no noise correction (RN = 0)
#   float                       → same RN for all subjects, td, and roi
#   {td: float}                 → fixed per td, same for all subjects and roi
#   {subj: float}               → fixed per subject, same for all td and roi
#   {subj: {td: float}}         → fixed per subject and td, same for all roi
#   {subj: {td: {roi: float}}}  → fixed per subject, td, and roi

# RN_FIXED = {
#     "BRAIN": {76.0: 37.0, 90.0: 34.0, 120.0: 36.0, 143.4: 36.0, 210.0: 37.0},
#     "LUDG":  {90.0: 31.0, 120.0: 30.0, 143.4: 30.0, 210.0: 31.0},
#     "MBBL":  {90.0: 35.0, 120.0: 31.0, 143.4: 31.0, 210.0: 35.0},
# }

RN_FIXED = {
    "BRAIN": {
        76.0:  {"AntCC": 37, "MidAntCC": 38, "CentralCC": 48, "MidPostCC": 49, "PostCC": 53},
        90.0:  {"AntCC": 32, "MidAntCC": 38, "CentralCC": 36, "MidPostCC": 42, "PostCC": 36},
        120.0: {"AntCC": 36, "MidAntCC": 44, "CentralCC": 40, "MidPostCC": 46, "PostCC": 40},
        143.4: {"AntCC": 36, "MidAntCC": 44, "CentralCC": 40, "MidPostCC": 46, "PostCC": 40},
        210.0: {"AntCC": 37, "MidAntCC": 38, "CentralCC": 48, "MidPostCC": 49, "PostCC": 53},
    },
    "LUDG": {
        90.0:  {"AntCC": 31, "MidAntCC": 35, "CentralCC": 38, "MidPostCC": 48, "PostCC": 49},
        120.0: {"AntCC": 30, "MidAntCC": 42, "CentralCC": 34, "MidPostCC": 44, "PostCC": 44},
        143.4: {"AntCC": 30, "MidAntCC": 42, "CentralCC": 34, "MidPostCC": 44, "PostCC": 44},
        210.0: {"AntCC": 31, "MidAntCC": 35, "CentralCC": 38, "MidPostCC": 48, "PostCC": 49},
    },
    "MBBL": {
        90.0:  {"AntCC": 35, "MidAntCC": 40, "CentralCC": 40, "MidPostCC": 52, "PostCC": 51},
        120.0: {"AntCC": 31, "MidAntCC": 41, "CentralCC": 47, "MidPostCC": 49, "PostCC": 44},
        143.4: {"AntCC": 31, "MidAntCC": 41, "CentralCC": 47, "MidPostCC": 49, "PostCC": 44},
        210.0: {"AntCC": 35, "MidAntCC": 40, "CentralCC": 40, "MidPostCC": 52, "PostCC": 51},
    },
}

MODEL_NAME = 'free'

# %%
# ══════════════════════════════════════════════════════════════════════════════
# LOAD DATA
# ══════════════════════════════════════════════════════════════════════════════

df = pd.read_parquet(MASTER_PATH)

data = df[
    (df.row_kind == "signal_rotated") &
    (df.direction.isin(DIRECTIONS)) &
    (df.N.isin(N_LIST)) &
    (df.stat == "avg")
].copy()

missing_cols = [c for c in [G_COLUMN, Y_COLUMN, G_CORRECTION_COLUMN] if c is not None and c not in data.columns]
if missing_cols:
    raise KeyError(f"Missing column(s): {missing_cols}")

data["G_fit"] = data[G_COLUMN]
if G_CORRECTION_COLUMN is not None:
    data["G_fit"] = data["G_fit"] * data[G_CORRECTION_COLUMN]
data["y_raw"] = data["value"]   # raw signal — always kept to derive S0
data["y_fit"] = data[Y_COLUMN]

G_LABEL = f"Modulation gradient G [mT/m] ({G_COLUMN})"
Y_LABEL = f"{Y_COLUMN} [a.u.]"

if TD_LIST is not None:
    data = data[data.td_ms.isin(TD_LIST)]
if ROI_LIST is not None:
    data = data[data.roi.isin(ROI_LIST)]

print(f"Rows loaded: {len(data)}")
print("Groups (subj, roi, dir):", data.groupby(["subj", "roi", "direction"]).ngroups)
print(f"Gradient column: {G_COLUMN}" + (f" × {G_CORRECTION_COLUMN}" if G_CORRECTION_COLUMN else ""))
print(f"Signal column:   {Y_COLUMN}")
data[["subj", "roi", "direction", "td_ms", "N", "G_fit", "y_fit"]]
# Out:
# Rows loaded: 2860
# Groups (subj, roi, dir): 30
# Gradient column: g_thorsten × grad_correction_factor
# Signal column:   value
#          subj     roi direction  td_ms  N      G_fit       y_fit
# 5302    BRAIN   AntCC       tra   90.0  4   0.000000  250.168675
# 5303    BRAIN   AntCC       tra   90.0  4   6.213986  244.684694
# 5304    BRAIN   AntCC       tra   90.0  4  12.427971  228.825266
# 5305    BRAIN   AntCC       tra   90.0  4  18.641957  214.273122
# 5306    BRAIN   AntCC       tra   90.0  4  24.855943  194.742588
# ...       ...     ...       ...    ... ..        ...         ...
# 180395   MBBL  PostCC      long  210.0  8  35.446824   52.056472
# 180396   MBBL  PostCC      long  210.0  8  41.354627   50.485129
# 180397   MBBL  PostCC      long  210.0  8  47.262431   51.328731
# 180398   MBBL  PostCC      long  210.0  8  53.170235   52.411720
# 180399   MBBL  PostCC      long  210.0  8  59.078039   50.391365
#
# [2860 rows x 7 columns]

# %%
# ══════════════════════════════════════════════════════════════════════════════
# FIT FUNCTIONS
#
# Signal model:  S(G) = sqrt( M0² · S_model(α, G)² + RN² )
#                where  M0 = sqrt(S0² − RN²),  RN always fixed,  α is the only
#                free parameter. S0 is the measured signal at G ≈ 0.
# ══════════════════════════════════════════════════════════════════════════════

def _resolve_rn(subj, td, roi=None):
    # Return fixed RN for (subj, td, roi). Returns 0.0 when RN_FIXED is None.
    if RN_FIXED is None:
        return 0.0
    if isinstance(RN_FIXED, dict):
        first_key = next(iter(RN_FIXED))
        if isinstance(first_key, str):               # {subj: ...}
            subj_entry = RN_FIXED.get(subj)
            if subj_entry is None:
                return 0.0
            if isinstance(subj_entry, dict):         # {subj: {td: ...}}
                td_entry = subj_entry.get(float(td), subj_entry.get(td))
                if td_entry is None:
                    return 0.0
                if isinstance(td_entry, dict):       # {subj: {td: {roi: float}}}
                    return float(td_entry.get(roi, 0.0))
                return float(td_entry)               # {subj: {td: float}}
            return float(subj_entry)                 # {subj: float}
        return float(RN_FIXED.get(float(td), RN_FIXED.get(td, 0.0)))  # {td: float}
    return float(RN_FIXED)


def _m0_from_s0(s0_raw, rn):
    # M0 = sqrt(S0² − RN²). For value_norm returns M0/S0.
    m0 = np.sqrt(max(float(s0_raw)**2 - float(rn)**2, 0.0))
    if Y_COLUMN == "value_norm":
        return m0 / float(s0_raw) if float(s0_raw) > 0 else 1.0
    return m0


def _get_master_alpha(subj, roi, direction):
    # Look up a fixed α from the master table for one (subj, roi, direction) group.
    rows = df[
        (df.subj == subj) & (df.roi == roi) & (df.direction == direction)
    ]
    col = ALPHA_MASTER_COL
    if col in rows.columns and not rows[col].isna().all():
        return float(rows[col].dropna().iloc[0])
    raise KeyError(f"'{col}' not found or all-NaN for {subj}/{roi}/{direction}")


def _predict(td, G, N, alpha, M0, rn):
    # Predicted signal: sqrt( (M0·S_model)² + RN² )
    with np.errstate(over="ignore", invalid="ignore"):
        sig = M_ogse_tort(td, G, N, td / N, alpha, M0, D0_FIXED)
        return np.sqrt(sig**2 + rn**2) if rn != 0.0 else sig


def _alpha_stderr(result):
    # 1-σ error on α from the least-squares Jacobian.
    dof = result.fun.size - result.x.size
    if dof <= 0 or result.x.size == 0:
        return np.nan
    try:
        cov = np.linalg.pinv(result.jac.T @ result.jac) * (2.0 * result.cost / dof)
        return float(np.sqrt(max(float(cov[0, 0]), 0.0)))
    except np.linalg.LinAlgError:
        return np.nan


def fit_curve(td, N, G, y, subj=None, roi=None, direction=None, s0=None):
    # Fit α for ONE (td, N) curve. M0 = sqrt(S0² − RN²) is derived, not fitted.
    rn = _resolve_rn(subj, td, roi)
    M0 = _m0_from_s0(s0, rn) if s0 is not None else float(y.max())

    if ALPHA_FIXED is not None:
        alpha_val = (
            _get_master_alpha(subj, roi, direction)
            if ALPHA_FIXED == "master" else float(ALPHA_FIXED)
        )
        fun = _predict(td, G, N, alpha_val, M0, rn) - y
        return type("FixedResult", (), {
            "x": np.array([alpha_val]), "fun": fun,
            "jac": np.zeros((fun.size, 1)),
            "cost": 0.5 * float(np.sum(fun**2)), "success": True,
        })()

    def residuals(params):
        out = _predict(td, G, N, params[0], M0, rn) - y
        return np.where(np.isfinite(out), out, 1e6)

    return least_squares(
        residuals, [ALPHA_INIT],
        bounds=([ALPHA_BOUNDS[0]], [ALPHA_BOUNDS[1]]),
        method="trf", max_nfev=10000,
    )


def fit_group_global_alpha(group_df):
    # Fit one shared α across ALL curves in group_df.
    # M0 = sqrt(S0² − RN²) is derived per curve; RN is fixed.
    # Returns: (result, curves, alpha, alpha_err, M0s)
    curves = []
    for (subj, roi, direction), dir_grp in group_df.groupby(["subj", "roi", "direction"]):
        for td in sorted(float(t) for t in dir_grp.td_ms.unique()):
            sub = dir_grp[np.isclose(dir_grp.td_ms.astype(float), td)]
            for N in N_LIST:
                s = sub[sub.N == N].sort_values("G_fit")
                if s.empty:
                    continue
                s0_raw = float(s.loc[s.G_fit.abs() == s.G_fit.abs().min(), "y_raw"].iloc[0])
                rn = _resolve_rn(subj, td, roi)
                curves.append(dict(
                    subj=subj, roi=roi, direction=direction,
                    td=td, N=int(N), S0=s0_raw,
                    G=s.G_fit.values, y=s.y_fit.values,
                    M0=_m0_from_s0(s0_raw, rn), rn=rn,
                ))

    M0s = {(c["subj"], c["roi"], c["direction"], c["td"], c["N"]): c["M0"] for c in curves}

    if ALPHA_FIXED is not None:
        # "master" → per-curve alpha from master table; float → same for all
        def _alpha_for_curve(c):
            if ALPHA_FIXED == "master":
                return _get_master_alpha(c["subj"], c["roi"], c["direction"])
            return float(ALPHA_FIXED)

        all_alphas = [_alpha_for_curve(c) for c in curves]
        fun = np.concatenate([
            _predict(c["td"], c["G"], c["N"], a, c["M0"], c["rn"]) - c["y"]
            for c, a in zip(curves, all_alphas)
        ])
        # Return the mean alpha (or the single pinned value) for the group summary
        alpha_summary = float(np.mean(all_alphas))
        result = type("FixedResult", (), {
            "x": np.array([alpha_summary]), "fun": fun,
            "jac": np.zeros((fun.size, 1)),
            "cost": 0.5 * float(np.sum(fun**2)), "success": True,
        })()
        # Store per-curve alpha in M0s dict (reuse pattern via separate return)
        return result, curves, alpha_summary, np.nan, M0s, all_alphas

    def residuals(params):
        alpha = float(params[0])
        res = []
        for c in curves:
            out = _predict(c["td"], c["G"], c["N"], alpha, c["M0"], c["rn"]) - c["y"]
            res.append(np.where(np.isfinite(out), out, 1e6))
        return np.concatenate(res)

    result = least_squares(
        residuals, [ALPHA_INIT],
        bounds=([ALPHA_BOUNDS[0]], [ALPHA_BOUNDS[1]]),
        method="trf", max_nfev=10000,
    )
    alpha_global = float(result.x[0])
    return result, curves, alpha_global, _alpha_stderr(result), M0s, [alpha_global] * len(curves)


_ALPHA_SCOPE_COLS = {
    "direction": ["subj", "roi", "direction"],
    "roi":       ["subj", "roi"],
    "subj":      ["subj"],
    "all":       [],
}

# %%
# ══════════════════════════════════════════════════════════════════════════════
# FIT LOOP  —  runs all (subj, roi, dir, td, N) groups
# ══════════════════════════════════════════════════════════════════════════════

rows      = []
fit_store = {}

if ALPHA_GLOBAL is None:
    # ── Per-curve fit: one α per (subj, roi, dir, td, N) ──────────────────────
    for (subj, roi, direction), grp in data.groupby(["subj", "roi", "direction"]):
        tds = sorted(float(t) for t in grp.td_ms.unique())
        fit_store[(subj, roi, direction)] = {"tds": tds, "fits": {td: {} for td in tds}}

        for td in tds:
            sub = grp[np.isclose(grp.td_ms.astype(float), td)]
            for N in N_LIST:
                s = sub[sub.N == N].sort_values("G_fit")
                if s.empty:
                    continue
                G, y = s.G_fit.values, s.y_fit.values
                s0_raw = float(s.loc[s.G_fit.abs() == s.G_fit.abs().min(), "y_raw"].iloc[0])
                result = fit_curve(td, N, G, y, subj=subj, roi=roi, direction=direction, s0=s0_raw)
                alpha  = float(result.x[0])
                rn     = _resolve_rn(subj, td, roi)
                M0     = _m0_from_s0(s0_raw, rn)

                print(
                    f"{subj:6s}  {roi:25s}  {direction}  td={td:5.0f} ms  N={N}  "
                    f"α={alpha:.4f}  M0={M0:.2f}  RN={rn:.2f}  cost={result.cost:.3e}"
                )
                fit_store[(subj, roi, direction)]["fits"][td][N] = dict(
                    G=G, y=y, M0=M0, alpha=alpha, RN=rn, S0=s0_raw,
                )
                rows.append(dict(
                    subj=subj, roi=roi, direction=direction, td_ms=td, N=N,
                    M0=M0, alpha=alpha, D0_m2ms=D0_FIXED, RN=rn,
                    alpha_err=_alpha_stderr(result), M0_err=np.nan, RN_err=np.nan,
                    model_name=MODEL_NAME,
                    g_column=G_COLUMN, g_correction_column=G_CORRECTION_COLUMN, y_column=Y_COLUMN,
                    cost=float(result.cost), success=bool(result.success),
                ))

else:
    # ── Global α fit: one α shared across a group of curves ───────────────────
    scope_cols = _ALPHA_SCOPE_COLS[ALPHA_GLOBAL]
    groups = data.groupby(scope_cols) if scope_cols else [("all", data)]

    for group_key, group_df in groups:
        result, curves, alpha_global, alpha_err, M0s, per_curve_alphas = fit_group_global_alpha(group_df)
        key_str = "  ".join(str(k) for k in group_key) if isinstance(group_key, tuple) else str(group_key)
        print(f"[{key_str}]  α={alpha_global:.4f}  cost={result.cost:.3e}")

        for (subj, roi, direction), sub_grp in group_df.groupby(["subj", "roi", "direction"]):
            if (subj, roi, direction) not in fit_store:
                tds_srd = sorted(float(t) for t in sub_grp.td_ms.unique())
                fit_store[(subj, roi, direction)] = {"tds": tds_srd, "fits": {t: {} for t in tds_srd}}

        for c, c_alpha in zip(curves, per_curve_alphas):
            subj, roi, direction, td, N = c["subj"], c["roi"], c["direction"], c["td"], c["N"]
            M0 = M0s[(subj, roi, direction, td, N)]
            fit_store[(subj, roi, direction)]["fits"][td][N] = dict(
                G=c["G"], y=c["y"], M0=M0, alpha=c_alpha, RN=c["rn"], S0=c["S0"],
            )
            rows.append(dict(
                subj=subj, roi=roi, direction=direction, td_ms=td, N=N,
                M0=M0, alpha=c_alpha, D0_m2ms=D0_FIXED, RN=c["rn"],
                alpha_err=alpha_err, M0_err=np.nan, RN_err=np.nan,
                model_name=MODEL_NAME,
                g_column=G_COLUMN, g_correction_column=G_CORRECTION_COLUMN, y_column=Y_COLUMN,
                cost=float(result.cost), success=bool(result.success),
            ))
# Out:
# BRAIN   AntCC                      long  td=   76 ms  N=4  α=1.0000  M0=245.49  RN=37.00  cost=5.839e+03
# BRAIN   AntCC                      long  td=   76 ms  N=8  α=1.0000  M0=276.62  RN=37.00  cost=1.495e+03
# BRAIN   AntCC                      long  td=   90 ms  N=4  α=1.0000  M0=248.11  RN=32.00  cost=3.376e+03
# BRAIN   AntCC                      long  td=   90 ms  N=8  α=1.0000  M0=245.35  RN=32.00  cost=2.656e+03
# BRAIN   AntCC                      long  td=  120 ms  N=4  α=1.0000  M0=183.13  RN=36.00  cost=2.502e+03
# BRAIN   AntCC                      long  td=  120 ms  N=8  α=1.0000  M0=177.84  RN=36.00  cost=1.935e+03
# BRAIN   AntCC                      long  td=  143 ms  N=4  α=1.0000  M0=192.93  RN=36.00  cost=3.036e+02
# BRAIN   AntCC                      long  td=  143 ms  N=8  α=1.0000  M0=158.45  RN=36.00  cost=1.477e+03
# BRAIN   AntCC                      long  td=  210 ms  N=4  α=1.0000  M0=137.03  RN=37.00  cost=6.297e+01
# BRAIN   AntCC                      long  td=  210 ms  N=8  α=1.0000  M0=140.02  RN=37.00  cost=1.547e+02
# BRAIN   AntCC                      tra  td=   76 ms  N=4  α=1.0000  M0=245.49  RN=37.00  cost=1.512e+04
# BRAIN   AntCC                      tra  td=   76 ms  N=8  α=1.0000  M0=276.62  RN=37.00  cost=2.185e+03
# BRAIN   AntCC                      tra  td=   90 ms  N=4  α=1.0000  M0=248.11  RN=32.00  cost=1.884e+04
# BRAIN   AntCC                      tra  td=   90 ms  N=8  α=1.0000  M0=245.35  RN=32.00  cost=5.081e+03
# BRAIN   AntCC                      tra  td=  120 ms  N=4  α=1.0000  M0=183.13  RN=36.00  cost=8.717e+03
# BRAIN   AntCC                      tra  td=  120 ms  N=8  α=1.0000  M0=177.84  RN=36.00  cost=5.991e+03
# BRAIN   AntCC                      tra  td=  143 ms  N=4  α=1.0000  M0=192.93  RN=36.00  cost=2.900e+03
# BRAIN   AntCC                      tra  td=  143 ms  N=8  α=1.0000  M0=158.45  RN=36.00  cost=4.943e+03
# BRAIN   AntCC                      tra  td=  210 ms  N=4  α=1.0000  M0=137.03  RN=37.00  cost=1.439e+02
# BRAIN   AntCC                      tra  td=  210 ms  N=8  α=1.0000  M0=140.02  RN=37.00  cost=2.398e+02
# BRAIN   CentralCC                  long  td=   76 ms  N=4  α=1.0000  M0=360.01  RN=48.00  cost=7.680e+03
# BRAIN   CentralCC                  long  td=   76 ms  N=8  α=1.0000  M0=388.03  RN=48.00  cost=5.283e+03
# BRAIN   CentralCC                  long  td=   90 ms  N=4  α=1.0000  M0=300.19  RN=36.00  cost=6.571e+03
# BRAIN   CentralCC                  long  td=   90 ms  N=8  α=1.0000  M0=306.94  RN=36.00  cost=2.860e+03
# BRAIN   CentralCC                  long  td=  120 ms  N=4  α=1.0000  M0=250.39  RN=40.00  cost=2.718e+03
# BRAIN   CentralCC                  long  td=  120 ms  N=8  α=1.0000  M0=244.64  RN=40.00  cost=4.815e+03
# BRAIN   CentralCC                  long  td=  143 ms  N=4  α=1.0000  M0=263.45  RN=40.00  cost=9.964e+02
# BRAIN   CentralCC                  long  td=  143 ms  N=8  α=1.0000  M0=250.56  RN=40.00  cost=3.749e+03
# BRAIN   CentralCC                  long  td=  210 ms  N=4  α=1.0000  M0=260.66  RN=48.00  cost=2.592e+02
# BRAIN   CentralCC                  long  td=  210 ms  N=8  α=1.0000  M0=214.10  RN=48.00  cost=6.021e+02
# BRAIN   CentralCC                  tra  td=   76 ms  N=4  α=1.0000  M0=360.01  RN=48.00  cost=1.435e+04
# BRAIN   CentralCC                  tra  td=   76 ms  N=8  α=1.0000  M0=388.03  RN=48.00  cost=5.129e+03
# BRAIN   CentralCC                  tra  td=   90 ms  N=4  α=1.0000  M0=300.19  RN=36.00  cost=2.863e+04
# BRAIN   CentralCC                  tra  td=   90 ms  N=8  α=1.0000  M0=306.94  RN=36.00  cost=1.019e+04
# BRAIN   CentralCC                  tra  td=  120 ms  N=4  α=1.0000  M0=250.39  RN=40.00  cost=1.574e+04
# BRAIN   CentralCC                  tra  td=  120 ms  N=8  α=1.0000  M0=244.64  RN=40.00  cost=1.279e+04
# BRAIN   CentralCC                  tra  td=  143 ms  N=4  α=1.0000  M0=263.45  RN=40.00  cost=6.482e+03
# BRAIN   CentralCC                  tra  td=  143 ms  N=8  α=1.0000  M0=250.56  RN=40.00  cost=1.097e+04
# BRAIN   CentralCC                  tra  td=  210 ms  N=4  α=1.0000  M0=260.66  RN=48.00  cost=5.333e+02
# BRAIN   CentralCC                  tra  td=  210 ms  N=8  α=1.0000  M0=214.10  RN=48.00  cost=9.554e+02
# BRAIN   MidAntCC                   long  td=   76 ms  N=4  α=1.0000  M0=293.96  RN=38.00  cost=6.925e+03
# BRAIN   MidAntCC                   long  td=   76 ms  N=8  α=1.0000  M0=313.48  RN=38.00  cost=1.655e+03
# BRAIN   MidAntCC                   long  td=   90 ms  N=4  α=1.0000  M0=286.43  RN=38.00  cost=5.877e+03
# BRAIN   MidAntCC                   long  td=   90 ms  N=8  α=1.0000  M0=290.23  RN=38.00  cost=2.830e+03
# BRAIN   MidAntCC                   long  td=  120 ms  N=4  α=1.0000  M0=245.89  RN=44.00  cost=1.947e+03
# BRAIN   MidAntCC                   long  td=  120 ms  N=8  α=1.0000  M0=237.12  RN=44.00  cost=2.827e+03
# BRAIN   MidAntCC                   long  td=  143 ms  N=4  α=1.0000  M0=239.16  RN=44.00  cost=6.979e+02
# BRAIN   MidAntCC                   long  td=  143 ms  N=8  α=1.0000  M0=238.51  RN=44.00  cost=2.619e+03
# BRAIN   MidAntCC                   long  td=  210 ms  N=4  α=1.0000  M0=154.17  RN=38.00  cost=1.123e+02
# BRAIN   MidAntCC                   long  td=  210 ms  N=8  α=1.0000  M0=151.40  RN=38.00  cost=1.003e+02
# BRAIN   MidAntCC                   tra  td=   76 ms  N=4  α=1.0000  M0=293.96  RN=38.00  cost=1.444e+04
# BRAIN   MidAntCC                   tra  td=   76 ms  N=8  α=1.0000  M0=313.48  RN=38.00  cost=2.038e+03
# BRAIN   MidAntCC                   tra  td=   90 ms  N=4  α=1.0000  M0=286.43  RN=38.00  cost=2.129e+04
# BRAIN   MidAntCC                   tra  td=   90 ms  N=8  α=1.0000  M0=290.23  RN=38.00  cost=6.004e+03
# BRAIN   MidAntCC                   tra  td=  120 ms  N=4  α=1.0000  M0=245.89  RN=44.00  cost=8.554e+03
# BRAIN   MidAntCC                   tra  td=  120 ms  N=8  α=1.0000  M0=237.12  RN=44.00  cost=6.470e+03
# BRAIN   MidAntCC                   tra  td=  143 ms  N=4  α=1.0000  M0=239.16  RN=44.00  cost=2.786e+03
# BRAIN   MidAntCC                   tra  td=  143 ms  N=8  α=1.0000  M0=238.51  RN=44.00  cost=5.392e+03
# BRAIN   MidAntCC                   tra  td=  210 ms  N=4  α=1.0000  M0=154.17  RN=38.00  cost=1.251e+02
# BRAIN   MidAntCC                   tra  td=  210 ms  N=8  α=1.0000  M0=151.40  RN=38.00  cost=4.458e+02
# BRAIN   MidPostCC                  long  td=   76 ms  N=4  α=1.0000  M0=329.40  RN=49.00  cost=4.273e+03
# BRAIN   MidPostCC                  long  td=   76 ms  N=8  α=1.0000  M0=364.23  RN=49.00  cost=5.756e+03
# BRAIN   MidPostCC                  long  td=   90 ms  N=4  α=1.0000  M0=369.78  RN=42.00  cost=7.043e+03
# BRAIN   MidPostCC                  long  td=   90 ms  N=8  α=1.0000  M0=345.44  RN=42.00  cost=4.080e+03
# BRAIN   MidPostCC                  long  td=  120 ms  N=4  α=1.0000  M0=353.51  RN=46.00  cost=2.465e+03
# BRAIN   MidPostCC                  long  td=  120 ms  N=8  α=1.0000  M0=351.75  RN=46.00  cost=5.476e+03
# BRAIN   MidPostCC                  long  td=  143 ms  N=4  α=1.0000  M0=288.51  RN=46.00  cost=1.319e+03
# BRAIN   MidPostCC                  long  td=  143 ms  N=8  α=1.0000  M0=286.05  RN=46.00  cost=3.726e+03
# BRAIN   MidPostCC                  long  td=  210 ms  N=4  α=1.0000  M0=261.43  RN=49.00  cost=3.464e+01
# BRAIN   MidPostCC                  long  td=  210 ms  N=8  α=1.0000  M0=183.64  RN=49.00  cost=4.194e+02
# BRAIN   MidPostCC                  tra  td=   76 ms  N=4  α=1.0000  M0=329.40  RN=49.00  cost=1.712e+04
# BRAIN   MidPostCC                  tra  td=   76 ms  N=8  α=1.0000  M0=364.23  RN=49.00  cost=7.521e+03
# BRAIN   MidPostCC                  tra  td=   90 ms  N=4  α=1.0000  M0=369.78  RN=42.00  cost=2.981e+04
# BRAIN   MidPostCC                  tra  td=   90 ms  N=8  α=1.0000  M0=345.44  RN=42.00  cost=9.160e+03
# BRAIN   MidPostCC                  tra  td=  120 ms  N=4  α=1.0000  M0=353.51  RN=46.00  cost=1.576e+04
# BRAIN   MidPostCC                  tra  td=  120 ms  N=8  α=1.0000  M0=351.75  RN=46.00  cost=1.600e+04
# BRAIN   MidPostCC                  tra  td=  143 ms  N=4  α=1.0000  M0=288.51  RN=46.00  cost=8.056e+03
# BRAIN   MidPostCC                  tra  td=  143 ms  N=8  α=1.0000  M0=286.05  RN=46.00  cost=1.448e+04
# BRAIN   MidPostCC                  tra  td=  210 ms  N=4  α=1.0000  M0=261.43  RN=49.00  cost=8.080e+02
# BRAIN   MidPostCC                  tra  td=  210 ms  N=8  α=1.0000  M0=183.64  RN=49.00  cost=1.603e+03
# BRAIN   PostCC                     long  td=   76 ms  N=4  α=1.0000  M0=271.90  RN=53.00  cost=2.775e+03
# BRAIN   PostCC                     long  td=   76 ms  N=8  α=1.0000  M0=290.75  RN=53.00  cost=2.647e+03
# BRAIN   PostCC                     long  td=   90 ms  N=4  α=1.0000  M0=271.08  RN=36.00  cost=3.816e+03
# BRAIN   PostCC                     long  td=   90 ms  N=8  α=1.0000  M0=256.28  RN=36.00  cost=3.317e+03
# BRAIN   PostCC                     long  td=  120 ms  N=4  α=1.0000  M0=220.07  RN=40.00  cost=1.026e+03
# BRAIN   PostCC                     long  td=  120 ms  N=8  α=1.0000  M0=212.55  RN=40.00  cost=2.434e+03
# BRAIN   PostCC                     long  td=  143 ms  N=4  α=1.0000  M0=187.13  RN=40.00  cost=6.073e+02
# BRAIN   PostCC                     long  td=  143 ms  N=8  α=1.0000  M0=190.82  RN=40.00  cost=1.441e+03
# BRAIN   PostCC                     long  td=  210 ms  N=4  α=1.0000  M0=203.66  RN=53.00  cost=2.959e+01
# BRAIN   PostCC                     long  td=  210 ms  N=8  α=1.0000  M0=160.56  RN=53.00  cost=1.571e+02
# BRAIN   PostCC                     tra  td=   76 ms  N=4  α=1.0000  M0=271.90  RN=53.00  cost=1.554e+04
# BRAIN   PostCC                     tra  td=   76 ms  N=8  α=1.0000  M0=290.75  RN=53.00  cost=3.475e+03
# BRAIN   PostCC                     tra  td=   90 ms  N=4  α=1.0000  M0=271.08  RN=36.00  cost=3.165e+04
# BRAIN   PostCC                     tra  td=   90 ms  N=8  α=1.0000  M0=256.28  RN=36.00  cost=1.019e+04
# BRAIN   PostCC                     tra  td=  120 ms  N=4  α=1.0000  M0=220.07  RN=40.00  cost=1.698e+04
# BRAIN   PostCC                     tra  td=  120 ms  N=8  α=1.0000  M0=212.55  RN=40.00  cost=1.088e+04
# BRAIN   PostCC                     tra  td=  143 ms  N=4  α=1.0000  M0=187.13  RN=40.00  cost=1.077e+04
# BRAIN   PostCC                     tra  td=  143 ms  N=8  α=1.0000  M0=190.82  RN=40.00  cost=1.210e+04
# BRAIN   PostCC                     tra  td=  210 ms  N=4  α=1.0000  M0=203.66  RN=53.00  cost=8.121e+02
# BRAIN   PostCC                     tra  td=  210 ms  N=8  α=1.0000  M0=160.56  RN=53.00  cost=9.777e+02
# LUDG    AntCC                      long  td=   90 ms  N=4  α=1.0000  M0=266.04  RN=31.00  cost=4.626e+03
# LUDG    AntCC                      long  td=   90 ms  N=8  α=1.0000  M0=281.12  RN=31.00  cost=2.301e+03
# LUDG    AntCC                      long  td=  120 ms  N=4  α=1.0000  M0=247.03  RN=30.00  cost=1.568e+03
# LUDG    AntCC                      long  td=  120 ms  N=8  α=1.0000  M0=231.94  RN=30.00  cost=3.144e+03
# LUDG    AntCC                      long  td=  143 ms  N=4  α=1.0000  M0=231.24  RN=30.00  cost=1.124e+03
# LUDG    AntCC                      long  td=  143 ms  N=8  α=1.0000  M0=212.55  RN=30.00  cost=1.424e+03
# LUDG    AntCC                      long  td=  210 ms  N=4  α=1.0000  M0=158.13  RN=31.00  cost=5.589e+01
# LUDG    AntCC                      long  td=  210 ms  N=8  α=1.0000  M0=156.74  RN=31.00  cost=2.666e+02
# LUDG    AntCC                      tra  td=   90 ms  N=4  α=1.0000  M0=266.04  RN=31.00  cost=2.208e+04
# LUDG    AntCC                      tra  td=   90 ms  N=8  α=1.0000  M0=281.12  RN=31.00  cost=7.437e+03
# LUDG    AntCC                      tra  td=  120 ms  N=4  α=1.0000  M0=247.03  RN=30.00  cost=1.097e+04
# LUDG    AntCC                      tra  td=  120 ms  N=8  α=1.0000  M0=231.94  RN=30.00  cost=8.940e+03
# LUDG    AntCC                      tra  td=  143 ms  N=4  α=1.0000  M0=231.24  RN=30.00  cost=4.518e+03
# LUDG    AntCC                      tra  td=  143 ms  N=8  α=1.0000  M0=212.55  RN=30.00  cost=5.571e+03
# LUDG    AntCC                      tra  td=  210 ms  N=4  α=1.0000  M0=158.13  RN=31.00  cost=2.696e+02
# LUDG    AntCC                      tra  td=  210 ms  N=8  α=1.0000  M0=156.74  RN=31.00  cost=3.714e+02
# LUDG    CentralCC                  long  td=   90 ms  N=4  α=1.0000  M0=345.19  RN=38.00  cost=1.072e+04
# LUDG    CentralCC                  long  td=   90 ms  N=8  α=1.0000  M0=345.68  RN=38.00  cost=7.178e+03
# LUDG    CentralCC                  long  td=  120 ms  N=4  α=1.0000  M0=376.39  RN=34.00  cost=7.021e+03
# LUDG    CentralCC                  long  td=  120 ms  N=8  α=1.0000  M0=366.00  RN=34.00  cost=9.758e+03
# LUDG    CentralCC                  long  td=  143 ms  N=4  α=1.0000  M0=249.47  RN=34.00  cost=1.995e+03
# LUDG    CentralCC                  long  td=  143 ms  N=8  α=1.0000  M0=283.18  RN=34.00  cost=5.314e+03
# LUDG    CentralCC                  long  td=  210 ms  N=4  α=1.0000  M0=168.42  RN=38.00  cost=3.180e+02
# LUDG    CentralCC                  long  td=  210 ms  N=8  α=1.0000  M0=175.06  RN=38.00  cost=7.535e+02
# LUDG    CentralCC                  tra  td=   90 ms  N=4  α=1.0000  M0=345.19  RN=38.00  cost=3.491e+04
# LUDG    CentralCC                  tra  td=   90 ms  N=8  α=1.0000  M0=345.68  RN=38.00  cost=1.315e+04
# LUDG    CentralCC                  tra  td=  120 ms  N=4  α=1.0000  M0=376.39  RN=34.00  cost=2.227e+04
# LUDG    CentralCC                  tra  td=  120 ms  N=8  α=1.0000  M0=366.00  RN=34.00  cost=1.985e+04
# LUDG    CentralCC                  tra  td=  143 ms  N=4  α=1.0000  M0=249.47  RN=34.00  cost=1.263e+04
# LUDG    CentralCC                  tra  td=  143 ms  N=8  α=1.0000  M0=283.18  RN=34.00  cost=1.471e+04
# LUDG    CentralCC                  tra  td=  210 ms  N=4  α=1.0000  M0=168.42  RN=38.00  cost=1.351e+03
# LUDG    CentralCC                  tra  td=  210 ms  N=8  α=1.0000  M0=175.06  RN=38.00  cost=1.928e+03
# LUDG    MidAntCC                   long  td=   90 ms  N=4  α=1.0000  M0=289.29  RN=35.00  cost=9.553e+03
# LUDG    MidAntCC                   long  td=   90 ms  N=8  α=1.0000  M0=320.85  RN=35.00  cost=7.235e+03
# LUDG    MidAntCC                   long  td=  120 ms  N=4  α=1.0000  M0=268.80  RN=42.00  cost=1.903e+03
# LUDG    MidAntCC                   long  td=  120 ms  N=8  α=1.0000  M0=268.81  RN=42.00  cost=4.645e+03
# LUDG    MidAntCC                   long  td=  143 ms  N=4  α=1.0000  M0=241.30  RN=42.00  cost=3.616e+03
# LUDG    MidAntCC                   long  td=  143 ms  N=8  α=1.0000  M0=223.81  RN=42.00  cost=2.509e+03
# LUDG    MidAntCC                   long  td=  210 ms  N=4  α=1.0000  M0=166.43  RN=35.00  cost=3.806e+01
# LUDG    MidAntCC                   long  td=  210 ms  N=8  α=1.0000  M0=160.32  RN=35.00  cost=2.765e+02
# LUDG    MidAntCC                   tra  td=   90 ms  N=4  α=1.0000  M0=289.29  RN=35.00  cost=2.928e+04
# LUDG    MidAntCC                   tra  td=   90 ms  N=8  α=1.0000  M0=320.85  RN=35.00  cost=1.027e+04
# LUDG    MidAntCC                   tra  td=  120 ms  N=4  α=1.0000  M0=268.80  RN=42.00  cost=1.085e+04
# LUDG    MidAntCC                   tra  td=  120 ms  N=8  α=1.0000  M0=268.81  RN=42.00  cost=1.333e+04
# LUDG    MidAntCC                   tra  td=  143 ms  N=4  α=1.0000  M0=241.30  RN=42.00  cost=4.754e+03
# LUDG    MidAntCC                   tra  td=  143 ms  N=8  α=1.0000  M0=223.81  RN=42.00  cost=6.757e+03
# LUDG    MidAntCC                   tra  td=  210 ms  N=4  α=1.0000  M0=166.43  RN=35.00  cost=4.812e+02
# LUDG    MidAntCC                   tra  td=  210 ms  N=8  α=1.0000  M0=160.32  RN=35.00  cost=7.678e+02
# LUDG    MidPostCC                  long  td=   90 ms  N=4  α=1.0000  M0=433.05  RN=48.00  cost=7.404e+03
# LUDG    MidPostCC                  long  td=   90 ms  N=8  α=1.0000  M0=446.23  RN=48.00  cost=4.820e+03
# LUDG    MidPostCC                  long  td=  120 ms  N=4  α=1.0000  M0=485.92  RN=44.00  cost=8.530e+03
# LUDG    MidPostCC                  long  td=  120 ms  N=8  α=1.0000  M0=480.82  RN=44.00  cost=7.487e+03
# LUDG    MidPostCC                  long  td=  143 ms  N=4  α=1.0000  M0=401.38  RN=44.00  cost=1.364e+03
# LUDG    MidPostCC                  long  td=  143 ms  N=8  α=1.0000  M0=419.27  RN=44.00  cost=5.327e+03
# LUDG    MidPostCC                  long  td=  210 ms  N=4  α=1.0000  M0=311.61  RN=48.00  cost=1.882e+02
# LUDG    MidPostCC                  long  td=  210 ms  N=8  α=1.0000  M0=313.10  RN=48.00  cost=1.666e+03
# LUDG    MidPostCC                  tra  td=   90 ms  N=4  α=1.0000  M0=433.05  RN=48.00  cost=2.620e+04
# LUDG    MidPostCC                  tra  td=   90 ms  N=8  α=1.0000  M0=446.23  RN=48.00  cost=1.020e+04
# LUDG    MidPostCC                  tra  td=  120 ms  N=4  α=1.0000  M0=485.92  RN=44.00  cost=1.879e+04
# LUDG    MidPostCC                  tra  td=  120 ms  N=8  α=1.0000  M0=480.82  RN=44.00  cost=1.398e+04
# LUDG    MidPostCC                  tra  td=  143 ms  N=4  α=1.0000  M0=401.38  RN=44.00  cost=8.120e+03
# LUDG    MidPostCC                  tra  td=  143 ms  N=8  α=1.0000  M0=419.27  RN=44.00  cost=1.056e+04
# LUDG    MidPostCC                  tra  td=  210 ms  N=4  α=1.0000  M0=311.61  RN=48.00  cost=8.384e+02
# LUDG    MidPostCC                  tra  td=  210 ms  N=8  α=1.0000  M0=313.10  RN=48.00  cost=1.507e+03
# LUDG    PostCC                     long  td=   90 ms  N=4  α=1.0000  M0=284.67  RN=49.00  cost=2.353e+03
# LUDG    PostCC                     long  td=   90 ms  N=8  α=1.0000  M0=283.04  RN=49.00  cost=3.583e+03
# LUDG    PostCC                     long  td=  120 ms  N=4  α=1.0000  M0=294.51  RN=44.00  cost=2.527e+03
# LUDG    PostCC                     long  td=  120 ms  N=8  α=1.0000  M0=305.52  RN=44.00  cost=4.236e+03
# LUDG    PostCC                     long  td=  143 ms  N=4  α=1.0000  M0=229.81  RN=44.00  cost=5.826e+02
# LUDG    PostCC                     long  td=  143 ms  N=8  α=1.0000  M0=233.75  RN=44.00  cost=2.049e+03
# LUDG    PostCC                     long  td=  210 ms  N=4  α=1.0000  M0=200.40  RN=49.00  cost=1.005e+02
# LUDG    PostCC                     long  td=  210 ms  N=8  α=1.0000  M0=191.58  RN=49.00  cost=4.117e+02
# LUDG    PostCC                     tra  td=   90 ms  N=4  α=1.0000  M0=284.67  RN=49.00  cost=2.727e+04
# LUDG    PostCC                     tra  td=   90 ms  N=8  α=1.0000  M0=283.04  RN=49.00  cost=1.076e+04
# LUDG    PostCC                     tra  td=  120 ms  N=4  α=1.0000  M0=294.51  RN=44.00  cost=2.107e+04
# LUDG    PostCC                     tra  td=  120 ms  N=8  α=1.0000  M0=305.52  RN=44.00  cost=1.547e+04
# LUDG    PostCC                     tra  td=  143 ms  N=4  α=1.0000  M0=229.81  RN=44.00  cost=1.091e+04
# LUDG    PostCC                     tra  td=  143 ms  N=8  α=1.0000  M0=233.75  RN=44.00  cost=1.219e+04
# LUDG    PostCC                     tra  td=  210 ms  N=4  α=1.0000  M0=200.40  RN=49.00  cost=7.417e+02
# LUDG    PostCC                     tra  td=  210 ms  N=8  α=1.0000  M0=191.58  RN=49.00  cost=1.074e+03
# MBBL    AntCC                      long  td=   90 ms  N=4  α=1.0000  M0=211.85  RN=35.00  cost=2.873e+03
# MBBL    AntCC                      long  td=   90 ms  N=8  α=1.0000  M0=214.17  RN=35.00  cost=3.023e+03
# MBBL    AntCC                      long  td=  120 ms  N=4  α=1.0000  M0=171.78  RN=31.00  cost=2.140e+03
# MBBL    AntCC                      long  td=  120 ms  N=8  α=1.0000  M0=170.11  RN=31.00  cost=3.205e+03
# MBBL    AntCC                      long  td=  143 ms  N=4  α=1.0000  M0=137.36  RN=31.00  cost=6.656e+02
# MBBL    AntCC                      long  td=  143 ms  N=8  α=1.0000  M0=154.21  RN=31.00  cost=1.372e+03
# MBBL    AntCC                      long  td=  210 ms  N=4  α=1.0000  M0=105.92  RN=35.00  cost=1.202e+02
# MBBL    AntCC                      long  td=  210 ms  N=8  α=1.0000  M0=110.80  RN=35.00  cost=1.512e+02
# MBBL    AntCC                      tra  td=   90 ms  N=4  α=1.0000  M0=211.85  RN=35.00  cost=2.018e+04
# MBBL    AntCC                      tra  td=   90 ms  N=8  α=1.0000  M0=214.17  RN=35.00  cost=8.358e+03
# MBBL    AntCC                      tra  td=  120 ms  N=4  α=1.0000  M0=171.78  RN=31.00  cost=8.528e+03
# MBBL    AntCC                      tra  td=  120 ms  N=8  α=1.0000  M0=170.11  RN=31.00  cost=8.211e+03
# MBBL    AntCC                      tra  td=  143 ms  N=4  α=1.0000  M0=137.36  RN=31.00  cost=4.042e+03
# MBBL    AntCC                      tra  td=  143 ms  N=8  α=1.0000  M0=154.21  RN=31.00  cost=4.587e+03
# MBBL    AntCC                      tra  td=  210 ms  N=4  α=1.0000  M0=105.92  RN=35.00  cost=2.016e+02
# MBBL    AntCC                      tra  td=  210 ms  N=8  α=1.0000  M0=110.80  RN=35.00  cost=3.355e+02
# MBBL    CentralCC                  long  td=   90 ms  N=4  α=1.0000  M0=363.68  RN=40.00  cost=1.095e+04
# MBBL    CentralCC                  long  td=   90 ms  N=8  α=1.0000  M0=367.67  RN=40.00  cost=7.262e+03
# MBBL    CentralCC                  long  td=  120 ms  N=4  α=1.0000  M0=324.23  RN=47.00  cost=4.609e+03
# MBBL    CentralCC                  long  td=  120 ms  N=8  α=1.0000  M0=336.70  RN=47.00  cost=7.016e+03
# MBBL    CentralCC                  long  td=  143 ms  N=4  α=1.0000  M0=295.24  RN=47.00  cost=1.088e+03
# MBBL    CentralCC                  long  td=  143 ms  N=8  α=1.0000  M0=306.25  RN=47.00  cost=3.899e+03
# MBBL    CentralCC                  long  td=  210 ms  N=4  α=1.0000  M0=213.93  RN=40.00  cost=5.442e+02
# MBBL    CentralCC                  long  td=  210 ms  N=8  α=1.0000  M0=232.03  RN=40.00  cost=7.325e+02
# MBBL    CentralCC                  tra  td=   90 ms  N=4  α=1.0000  M0=363.68  RN=40.00  cost=2.949e+04
# MBBL    CentralCC                  tra  td=   90 ms  N=8  α=1.0000  M0=367.67  RN=40.00  cost=1.365e+04
# MBBL    CentralCC                  tra  td=  120 ms  N=4  α=1.0000  M0=324.23  RN=47.00  cost=1.370e+04
# MBBL    CentralCC                  tra  td=  120 ms  N=8  α=1.0000  M0=336.70  RN=47.00  cost=1.298e+04
# MBBL    CentralCC                  tra  td=  143 ms  N=4  α=1.0000  M0=295.24  RN=47.00  cost=7.015e+03
# MBBL    CentralCC                  tra  td=  143 ms  N=8  α=1.0000  M0=306.25  RN=47.00  cost=9.494e+03
# MBBL    CentralCC                  tra  td=  210 ms  N=4  α=1.0000  M0=213.93  RN=40.00  cost=1.732e+03
# MBBL    CentralCC                  tra  td=  210 ms  N=8  α=1.0000  M0=232.03  RN=40.00  cost=2.225e+03
# MBBL    MidAntCC                   long  td=   90 ms  N=4  α=1.0000  M0=363.80  RN=40.00  cost=8.703e+03
# MBBL    MidAntCC                   long  td=   90 ms  N=8  α=1.0000  M0=355.49  RN=40.00  cost=8.163e+03
# MBBL    MidAntCC                   long  td=  120 ms  N=4  α=1.0000  M0=282.35  RN=41.00  cost=4.175e+03
# MBBL    MidAntCC                   long  td=  120 ms  N=8  α=1.0000  M0=279.06  RN=41.00  cost=5.190e+03
# MBBL    MidAntCC                   long  td=  143 ms  N=4  α=1.0000  M0=278.63  RN=41.00  cost=1.697e+03
# MBBL    MidAntCC                   long  td=  143 ms  N=8  α=1.0000  M0=243.75  RN=41.00  cost=3.760e+03
# MBBL    MidAntCC                   long  td=  210 ms  N=4  α=1.0000  M0=201.76  RN=40.00  cost=1.858e+02
# MBBL    MidAntCC                   long  td=  210 ms  N=8  α=1.0000  M0=211.33  RN=40.00  cost=5.862e+02
# MBBL    MidAntCC                   tra  td=   90 ms  N=4  α=1.0000  M0=363.80  RN=40.00  cost=2.470e+04
# MBBL    MidAntCC                   tra  td=   90 ms  N=8  α=1.0000  M0=355.49  RN=40.00  cost=1.117e+04
# MBBL    MidAntCC                   tra  td=  120 ms  N=4  α=1.0000  M0=282.35  RN=41.00  cost=1.206e+04
# MBBL    MidAntCC                   tra  td=  120 ms  N=8  α=1.0000  M0=279.06  RN=41.00  cost=1.121e+04
# MBBL    MidAntCC                   tra  td=  143 ms  N=4  α=1.0000  M0=278.63  RN=41.00  cost=4.756e+03
# MBBL    MidAntCC                   tra  td=  143 ms  N=8  α=1.0000  M0=243.75  RN=41.00  cost=6.533e+03
# MBBL    MidAntCC                   tra  td=  210 ms  N=4  α=1.0000  M0=201.76  RN=40.00  cost=5.987e+02
# MBBL    MidAntCC                   tra  td=  210 ms  N=8  α=1.0000  M0=211.33  RN=40.00  cost=1.050e+03
# MBBL    MidPostCC                  long  td=   90 ms  N=4  α=1.0000  M0=415.55  RN=52.00  cost=7.255e+03
# MBBL    MidPostCC                  long  td=   90 ms  N=8  α=1.0000  M0=404.81  RN=52.00  cost=1.006e+04
# MBBL    MidPostCC                  long  td=  120 ms  N=4  α=1.0000  M0=394.36  RN=49.00  cost=2.401e+03
# MBBL    MidPostCC                  long  td=  120 ms  N=8  α=1.0000  M0=379.37  RN=49.00  cost=6.983e+03
# MBBL    MidPostCC                  long  td=  143 ms  N=4  α=1.0000  M0=342.25  RN=49.00  cost=2.042e+03
# MBBL    MidPostCC                  long  td=  143 ms  N=8  α=1.0000  M0=345.44  RN=49.00  cost=2.747e+03
# MBBL    MidPostCC                  long  td=  210 ms  N=4  α=1.0000  M0=288.95  RN=52.00  cost=9.017e+01
# MBBL    MidPostCC                  long  td=  210 ms  N=8  α=1.0000  M0=272.72  RN=52.00  cost=2.544e+02
# MBBL    MidPostCC                  tra  td=   90 ms  N=4  α=1.0000  M0=415.55  RN=52.00  cost=2.043e+04
# MBBL    MidPostCC                  tra  td=   90 ms  N=8  α=1.0000  M0=404.81  RN=52.00  cost=1.366e+04
# MBBL    MidPostCC                  tra  td=  120 ms  N=4  α=1.0000  M0=394.36  RN=49.00  cost=8.429e+03
# MBBL    MidPostCC                  tra  td=  120 ms  N=8  α=1.0000  M0=379.37  RN=49.00  cost=1.427e+04
# MBBL    MidPostCC                  tra  td=  143 ms  N=4  α=1.0000  M0=342.25  RN=49.00  cost=6.550e+03
# MBBL    MidPostCC                  tra  td=  143 ms  N=8  α=1.0000  M0=345.44  RN=49.00  cost=7.515e+03
# MBBL    MidPostCC                  tra  td=  210 ms  N=4  α=1.0000  M0=288.95  RN=52.00  cost=6.037e+02
# MBBL    MidPostCC                  tra  td=  210 ms  N=8  α=1.0000  M0=272.72  RN=52.00  cost=1.139e+03
# MBBL    PostCC                     long  td=   90 ms  N=4  α=1.0000  M0=289.58  RN=51.00  cost=1.563e+03
# MBBL    PostCC                     long  td=   90 ms  N=8  α=1.0000  M0=280.22  RN=51.00  cost=4.475e+03
# MBBL    PostCC                     long  td=  120 ms  N=4  α=1.0000  M0=228.84  RN=44.00  cost=1.019e+03
# MBBL    PostCC                     long  td=  120 ms  N=8  α=1.0000  M0=244.57  RN=44.00  cost=3.514e+03
# MBBL    PostCC                     long  td=  143 ms  N=4  α=1.0000  M0=210.00  RN=44.00  cost=5.713e+02
# MBBL    PostCC                     long  td=  143 ms  N=8  α=1.0000  M0=187.10  RN=44.00  cost=1.332e+03
# MBBL    PostCC                     long  td=  210 ms  N=4  α=1.0000  M0=147.86  RN=51.00  cost=5.717e+01
# MBBL    PostCC                     long  td=  210 ms  N=8  α=1.0000  M0=146.09  RN=51.00  cost=8.140e+01
# MBBL    PostCC                     tra  td=   90 ms  N=4  α=1.0000  M0=289.58  RN=51.00  cost=2.482e+04
# MBBL    PostCC                     tra  td=   90 ms  N=8  α=1.0000  M0=280.22  RN=51.00  cost=1.184e+04
# MBBL    PostCC                     tra  td=  120 ms  N=4  α=1.0000  M0=228.84  RN=44.00  cost=1.376e+04
# MBBL    PostCC                     tra  td=  120 ms  N=8  α=1.0000  M0=244.57  RN=44.00  cost=1.113e+04
# MBBL    PostCC                     tra  td=  143 ms  N=4  α=1.0000  M0=210.00  RN=44.00  cost=6.653e+03
# MBBL    PostCC                     tra  td=  143 ms  N=8  α=1.0000  M0=187.10  RN=44.00  cost=8.355e+03
# MBBL    PostCC                     tra  td=  210 ms  N=4  α=1.0000  M0=147.86  RN=51.00  cost=5.946e+02
# MBBL    PostCC                     tra  td=  210 ms  N=8  α=1.0000  M0=146.09  RN=51.00  cost=7.984e+02

# %%
# ══════════════════════════════════════════════════════════════════════════════
# SAVE RESULTS TABLE
# Columns: subj, roi, direction, td_ms, N, alpha, alpha_err, M0, RN, cost, ...
# ══════════════════════════════════════════════════════════════════════════════

results_df = pd.DataFrame(rows)
results_df.to_excel(OUT_DIR / "fit_results.xlsx", index=False)
print(f"Saved {len(results_df)} rows → {OUT_DIR / 'fit_results.xlsx'}")
results_df
# Out:
# Saved 260 rows → ../../analysis/brains/ogse_experiments/lab/fit_free_CC-a1/fit_results.xlsx
#       subj     roi direction  td_ms  N          M0  alpha       D0_m2ms    RN  \
# 0    BRAIN   AntCC      long   76.0  4  245.487080    1.0  3.200000e-12  37.0
# 1    BRAIN   AntCC      long   76.0  8  276.616751    1.0  3.200000e-12  37.0
# 2    BRAIN   AntCC      long   90.0  4  248.113615    1.0  3.200000e-12  32.0
# 3    BRAIN   AntCC      long   90.0  8  245.347918    1.0  3.200000e-12  32.0
# 4    BRAIN   AntCC      long  120.0  4  183.129514    1.0  3.200000e-12  36.0
# ..     ...     ...       ...    ... ..         ...    ...           ...   ...
# 255   MBBL  PostCC       tra  120.0  8  244.573024    1.0  3.200000e-12  44.0
# 256   MBBL  PostCC       tra  143.4  4  210.004099    1.0  3.200000e-12  44.0
# 257   MBBL  PostCC       tra  143.4  8  187.101132    1.0  3.200000e-12  44.0
# 258   MBBL  PostCC       tra  210.0  4  147.858041    1.0  3.200000e-12  51.0
# 259   MBBL  PostCC       tra  210.0  8  146.090639    1.0  3.200000e-12  51.0
#
#      alpha_err  M0_err  RN_err model_name    g_column     g_correction_column  \
# 0          0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 1          0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 2          0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 3          0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 4          0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# ..         ...     ...     ...        ...         ...                     ...
# 255        0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 256        0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 257        0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 258        0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
# 259        0.0     NaN     NaN       free  g_thorsten  grad_correction_factor
#
#     y_column          cost  success
# 0      value   5838.858310     True
# 1      value   1495.122072     True
# 2      value   3375.689400     True
# 3      value   2656.433957     True
# 4      value   2501.513721     True
# ..       ...           ...      ...
# 255    value  11126.431108     True
# 256    value   6653.408885     True
# 257    value   8354.803681     True
# 258    value    594.612652     True
# 259    value    798.438287     True
#
# [260 rows x 18 columns]

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT FITS — raw signal with Rician noise correction
# One figure per (subj, roi, dir): data points + fitted S(G) per (td, N)
# Top row:    S(G) = sqrt( M0²·S_model(α,G)² + RN² )
# Bottom row: signal contrast  ΔS = S(N_hi) − S(N_lo)  vs G
# ══════════════════════════════════════════════════════════════════════════════

G_plot = np.linspace(0, float(data.G_fit.max()), 300)
N_hi, N_lo = N_LIST[-1], N_LIST[0]

for (subj, roi, direction), store in fit_store.items():
    tds   = store["tds"]
    n_tds = len(tds)

    fig, axes_grid = plt.subplots(2, n_tds, figsize=(4 * n_tds, 7), sharey="row", squeeze=False)
    axes      = axes_grid[0]
    diff_axes = axes_grid[1]

    for ax, dax, td in zip(axes, diff_axes, tds):
        fits_td = store["fits"][td]
        title_lines = [f"td = {td:.1f} ms"]
        y_hat_per_N = {}
        for N, color in zip(N_LIST, ["C0", "C1", "C2", "C3"]):
            fit = fits_td.get(N)
            if fit is None:
                continue
            ax.scatter(fit["G"], fit["y"], color=color, s=20, zorder=3, label=f"N={N} data")
            y_hat = _predict(td, G_plot, N, fit["alpha"], fit["M0"], fit["RN"])
            y_hat_per_N[N] = y_hat
            ax.plot(G_plot, y_hat, color=color, label=f"N={N} fit")
            title_lines.append(f"α(N={N}) = {fit['alpha']:.4f}  RN={fit['RN']:.3f}")
        ax.set_title("\n".join(title_lines), fontsize=7)
        ax.set_xlabel(G_LABEL)
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)
        if N_hi in y_hat_per_N and N_lo in y_hat_per_N:
            dax.plot(G_plot, y_hat_per_N[N_hi] - y_hat_per_N[N_lo], color="k")
            dax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
        dax.set_title(f"td = {td:.1f} ms  (N={N_hi} − N={N_lo})", fontsize=8)
        dax.set_xlabel(G_LABEL)
        dax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
        dax.set_axisbelow(True)

    axes[0].set_ylabel(Y_LABEL)
    diff_axes[0].set_ylabel(f"ΔS  (N={N_hi} − N={N_lo})")
    axes[0].legend(fontsize=6)
    fig.suptitle(f"{subj}  |  {roi}  |  {direction}", fontsize=9)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"fit_{subj}_{roi}_{direction}.png", dpi=120)
    plt.close(fig)

print("Fit plots saved.")
# Out:
# Fit plots saved.

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT α vs td  —  all subjects, grouped by ROI and direction
# One figure per direction; one panel per ROI
# Colour = subject (lighter → darker within ROI palette), linestyle = N
# ══════════════════════════════════════════════════════════════════════════════

rois     = sorted(results_df.roi.unique())
subjects = sorted(results_df.subj.unique())
roi_colors   = _roi_color_map(rois)
_N_ls        = ["-", "--", "-.", ":"]
N_linestyles = {N: ls for N, ls in zip(N_LIST, _N_ls)}

for direction in DIRECTIONS:
    sub = results_df[results_df.direction == direction]
    fig, axes = plt.subplots(1, len(rois), figsize=(4 * len(rois), 4), sharey=True)
    axes = np.atleast_1d(axes)

    for ax, roi in zip(axes, rois):
        base_color = roi_colors[roi]
        cmap = mcolors.LinearSegmentedColormap.from_list("", ["#cccccc", base_color])
        for i, subj in enumerate(subjects):
            shade  = cmap(0.3 + 0.7 * i / max(1, len(subjects) - 1))
            marker = DEFAULT_BRAIN_MARKERS[i % len(DEFAULT_BRAIN_MARKERS)]
            for N in N_LIST:
                g = (
                    sub[(sub.roi == roi) & (sub.subj == subj) & (sub.N == N)]
                    .drop_duplicates("td_ms").sort_values("td_ms")
                )
                if g.empty:
                    continue
                label = subj if N == N_LIST[0] else None
                ax.scatter(g.td_ms, g.alpha, color=shade, marker=marker, s=60, zorder=3)
                ax.plot(g.td_ms, g.alpha, color=shade, linewidth=0.8,
                        linestyle=N_linestyles[N], label=label)
        ax.set_title(roi, fontsize=9)
        ax.set_xlabel("td [ms]")
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)

    axes[0].set_ylabel("α [a.u.]")
    handles, labels = axes[0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels, fontsize=7, loc="upper right", ncol=1)
    n_handles = [mlines.Line2D([], [], color="gray", linestyle=N_linestyles[N], label=f"N={N}") for N in N_LIST]
    axes[-1].legend(handles=n_handles, fontsize=7, loc="lower right")
    fig.suptitle(f"α vs td — direction: {direction}", fontsize=10)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"alpha_vs_td_{direction}.png", dpi=120)
    plt.show()

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT NORMALIZED FITS  —  S_model(α, G) with M0 = 1, no Rician correction
# Useful to compare model shape across subjects/ROIs without amplitude effects
# Data is divided by fitted M0; model plotted as pure S_model ∈ [0, 1]
# ══════════════════════════════════════════════════════════════════════════════

for (subj, roi, direction), store in fit_store.items():
    tds   = store["tds"]
    n_tds = len(tds)

    fig, axes_grid = plt.subplots(2, n_tds, figsize=(4 * n_tds, 7), sharey="row", squeeze=False)
    axes      = axes_grid[0]
    diff_axes = axes_grid[1]

    for ax, dax, td in zip(axes, diff_axes, tds):
        fits_td = store["fits"][td]
        y_hat_per_N = {}
        for N, color in zip(N_LIST, ["C0", "C1", "C2", "C3"]):
            fit = fits_td.get(N)
            if fit is None:
                continue
            M0 = fit["M0"] if fit["M0"] != 0.0 else 1.0
            RN = fit["RN"]
            ax.scatter(fit["G"], np.sqrt( (fit["y"]**2 - RN**2) / M0**2 ), color=color, s=20, zorder=3, label=f"N={N} data")
            with np.errstate(over="ignore", invalid="ignore"):
                sig_norm = M_ogse_tort(td, G_plot, N, td / N, fit["alpha"], 1.0, D0_FIXED)
            y_hat_per_N[N] = sig_norm
            ax.plot(G_plot, sig_norm, color=color, label=f"N={N} model")
        ax.set_title(f"td = {td:.1f} ms", fontsize=8)
        ax.set_xlabel(G_LABEL)
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
        ax.set_axisbelow(True)
        if N_hi in y_hat_per_N and N_lo in y_hat_per_N:
            dax.plot(G_plot, y_hat_per_N[N_hi] - y_hat_per_N[N_lo], color="k")
            dax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
        dax.set_title(f"td = {td:.1f} ms  (N={N_hi} − N={N_lo})", fontsize=8)
        dax.set_xlabel(G_LABEL)
        dax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
        dax.set_axisbelow(True)

    axes[0].set_ylabel(f"{Y_COLUMN} / M0 [a.u.]")
    diff_axes[0].set_ylabel(f"ΔS  (N={N_hi} − N={N_lo})")
    axes[0].legend(fontsize=6)
    fig.suptitle(f"{subj}  |  {roi}  |  {direction}  |  S_model (no RN)", fontsize=9)
    fig.tight_layout()
    fig.savefig(OUT_DIR / f"fit_norm_{subj}_{roi}_{direction}.png", dpi=120)
    plt.close(fig)

print("Normalized model plots saved.")
# Out:
# /tmp/ipykernel_4153113/781656314.py:24: RuntimeWarning: invalid value encountered in sqrt
#   ax.scatter(fit["G"], np.sqrt( (fit["y"]**2 - RN**2) / M0**2 ), color=color, s=20, zorder=3, label=f"N={N} data")
# Normalized model plots saved.

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT α and M0 vs td  —  per subject
# Rows = ROIs, columns = directions, colour/linestyle = N
# Shaded band = ±1σ from the Jacobian covariance
# ══════════════════════════════════════════════════════════════════════════════

subjects_plot = sorted(results_df.subj.unique())
rois_plot     = sorted(results_df.roi.unique())
Ns_plot       = sorted(results_df.N.unique())
dirs_plot     = [d for d in ["long", "tra"] if d in results_df.direction.unique()]
_N_ls_p       = ["-", "--", "-.", ":"]
N_ls          = {N: _N_ls_p[i % len(_N_ls_p)] for i, N in enumerate(Ns_plot)}

for subj in subjects_plot:
    for param, ylabel in [("alpha", "α [a.u.]"), ("M0", "M0 [a.u.]")]:
        fig, axes = plt.subplots(
            len(rois_plot), len(dirs_plot),
            figsize=(4 * len(dirs_plot), 3 * len(rois_plot)),
            sharey=False, squeeze=False,
        )
        for i_roi, roi in enumerate(rois_plot):
            for i_dir, direction in enumerate(dirs_plot):
                ax = axes[i_roi, i_dir]
                s = results_df[
                    (results_df.subj == subj) &
                    (results_df.roi == roi) &
                    (results_df.direction == direction)
                ]
                for N in Ns_plot:
                    g = s[s.N == N].sort_values("td_ms")
                    if g.empty:
                        continue
                    line, = ax.plot(g.td_ms, g[param], linestyle=N_ls[N],
                                    marker="o", ms=4, linewidth=0.8, label=f"N={N}")
                    err_col = f"{param}_err"
                    if err_col in g.columns:
                        x    = g.td_ms.to_numpy(dtype=float)
                        yv   = g[param].to_numpy(dtype=float)
                        yerr = g[err_col].to_numpy(dtype=float)
                        ok   = np.isfinite(x) & np.isfinite(yv) & np.isfinite(yerr)
                        if np.any(ok):
                            ax.fill_between(x[ok], yv[ok] - yerr[ok], yv[ok] + yerr[ok],
                                            color=line.get_color(), alpha=0.18, linewidth=0)
                if i_roi == 0:
                    ax.set_title(direction, fontsize=9)
                if i_dir == 0:
                    ax.set_ylabel(f"{roi}\n{ylabel}", fontsize=8)
                ax.set_xlabel("td [ms]")
                ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
                ax.set_axisbelow(True)
                if i_roi == 0 and i_dir == len(dirs_plot) - 1:
                    ax.legend(fontsize=6, title="N", title_fontsize=6)
        fig.suptitle(f"{subj} — {param} vs td", fontsize=11)
        fig.tight_layout()
        fig.savefig(OUT_DIR / f"{param}_vs_td_{subj}.png", dpi=120)
        plt.close(fig)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT α and M0 vs td  —  per subject, log-scale y-axis
# Same layout as previous cell; useful to spot order-of-magnitude variation
# ══════════════════════════════════════════════════════════════════════════════

for subj in subjects_plot:
    for param, ylabel in [("alpha", "α [a.u.]"), ("M0", "M0 [a.u.]")]:
        fig, axes = plt.subplots(
            len(rois_plot), len(dirs_plot),
            figsize=(4 * len(dirs_plot), 3 * len(rois_plot)),
            sharey=False, squeeze=False,
        )
        for i_roi, roi in enumerate(rois_plot):
            for i_dir, direction in enumerate(dirs_plot):
                ax = axes[i_roi, i_dir]
                s = results_df[
                    (results_df.subj == subj) &
                    (results_df.roi == roi) &
                    (results_df.direction == direction)
                ]
                for N in Ns_plot:
                    g = s[s.N == N].sort_values("td_ms")
                    if g.empty:
                        continue
                    line, = ax.plot(g.td_ms, g[param], linestyle=N_ls[N],
                                    marker="o", ms=4, linewidth=0.8, label=f"N={N}")
                    err_col = f"{param}_err"
                    if err_col in g.columns:
                        x     = g.td_ms.to_numpy(dtype=float)
                        yv    = g[param].to_numpy(dtype=float)
                        yerr  = g[err_col].to_numpy(dtype=float)
                        lower = np.maximum(yv - yerr, np.finfo(float).tiny)
                        upper = yv + yerr
                        ok    = np.isfinite(x) & np.isfinite(yv) & np.isfinite(yerr) & (yv > 0) & (upper > 0)
                        if np.any(ok):
                            ax.fill_between(x[ok], lower[ok], upper[ok],
                                            color=line.get_color(), alpha=0.18, linewidth=0)
                ax.set_yscale("log")
                if i_roi == 0:
                    ax.set_title(direction, fontsize=9)
                if i_dir == 0:
                    ax.set_ylabel(f"{roi}\n{ylabel} (log)", fontsize=8)
                ax.set_xlabel("td [ms]")
                ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.6)
                ax.set_axisbelow(True)
                if i_roi == 0 and i_dir == len(dirs_plot) - 1:
                    ax.legend(fontsize=6, title="N", title_fontsize=6)
        fig.suptitle(f"{subj} — {param} vs td  (log scale)", fontsize=11)
        fig.tight_layout()
        fig.savefig(OUT_DIR / f"{param}_vs_td_log_{subj}.png", dpi=120)
        plt.close(fig)

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PLOT SIGNAL CONTRAST  ΔS = S(N_hi) − S(N_lo)  vs G, Ld, Lcf, lcf
# Per subject: rows = ROIs, columns = directions, colour = td
# "_raw"  uses the full model:  sqrt( M0²·S_model² + RN² )
# "_corr" uses the clean model: M0·S_model(α, G)  (no Rician term)
# ══════════════════════════════════════════════════════════════════════════════
# ── Per-subject contrast figures: ROIs × directions, contrast curves per td ──
# _raw  = full fit including RN noise:  sqrt(sig² + rn²)
# _corr = clean model, no noise:        sig
td_cmap    = plt.cm.viridis
N_hi, N_lo = 8, 4
G_plot     = np.linspace(0, float(data.G_fit.max()), 300)
PEAK_GAMMA = 267.5221900   # rad / (ms · mT), proton gyromagnetic ratio

def _x_for_td(td_ms, xvar):
    if xvar == "G":
        return G_plot.copy()
    D0, gamma = float(D0_PLOT), float(PEAK_GAMMA)
    l_d = np.sqrt(D0 * float(td_ms))
    l_G = np.full_like(G_plot, np.nan)
    valid = G_plot > 0
    l_G[valid] = (D0 / (gamma * G_plot[valid])) ** (1.0 / 3.0)
    Ld  = l_d / l_G
    Lcf = 1.5 ** 0.25 / np.sqrt(Ld)
    lcf = Lcf * l_G * 1e6
    if xvar == "Ld":  return Ld
    if xvar == "Lcf": return Lcf
    if xvar == "lcf": return lcf
    raise ValueError(xvar)

X_AXES = [
    ("G",   G_LABEL),
    ("Ld",  "Lᵈ (dimensionless)"),
    ("Lcf", "Lcf (dimensionless)"),
    ("lcf", "lcf [µm]"),
]

D0_PLOT = D0_FIXED

# ── precompute contrasts ───────────────────────────────────────────────────────
raw_contrast_store  = {}   # sqrt(sig² + rn²)
corr_contrast_store = {}   # sig only

for (subj, roi, direction), store in fit_store.items():
    for td in store["tds"]:
        raw_per_N  = {}
        corr_per_N = {}
        for N in N_LIST:
            fit = store["fits"][td].get(N)
            if fit is None:
                continue
            rn = fit.get("RN", 0.0)
            with np.errstate(over="ignore", invalid="ignore"):
                sig   = M_ogse_tort(td, G_plot, N, td / N, fit["alpha"], 1, D0_FIXED)
                y_hat = np.sqrt( sig**2 + (rn**2)/(fit["M0"]**2) ) if rn != 0.0 else sig
            raw_per_N[N]  = y_hat
            corr_per_N[N] = sig
        if N_hi in raw_per_N and N_lo in raw_per_N:
            raw_contrast_store[(subj, roi, direction, td)]  = raw_per_N[N_hi]  - raw_per_N[N_lo]
        if N_hi in corr_per_N and N_lo in corr_per_N:
            corr_contrast_store[(subj, roi, direction, td)] = corr_per_N[N_hi] - corr_per_N[N_lo]

# ── helper ─────────────────────────────────────────────────────────────────────
def _plot_contrast(cstore, xvar, xlabel, subj, suffix, title_tag):
    rois_subj = sorted(set(k[1] for k in cstore if k[0] == subj))
    dirs_subj = [d for d in DIRECTIONS if any(k[2] == d for k in cstore if k[0] == subj)]
    n_rois, n_dirs = len(rois_subj), len(dirs_subj)
    if n_rois == 0 or n_dirs == 0:
        return
    all_tds_subj = sorted(set(k[3] for k in cstore if k[0] == subj))
    colors_leg   = [td_cmap(i / max(1, len(all_tds_subj) - 1)) for i in range(len(all_tds_subj))]
    leg_handles  = [plt.Line2D([0], [0], color=c, linewidth=1.5) for c in colors_leg]
    leg_labels   = [f"td={td:.0f} ms" for td in all_tds_subj]
    td_color_map = {td: c for td, c in zip(all_tds_subj, colors_leg)}
    fig, axes = plt.subplots(n_rois, n_dirs, figsize=(4 * n_dirs, 3 * n_rois), squeeze=False)
    for i_roi, roi in enumerate(rois_subj):
        for i_dir, direction in enumerate(dirs_subj):
            ax = axes[i_roi, i_dir]
            tds_here = sorted(k[3] for k in cstore
                              if k[0] == subj and k[1] == roi and k[2] == direction)
            if not tds_here:
                ax.set_visible(False)
                continue
            for td in tds_here:
                ax.plot(_x_for_td(td, xvar), cstore[(subj, roi, direction, td)],
                        color=td_color_map[td], linewidth=1.2)
            ax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
            if i_roi == 0:
                ax.set_title(direction, fontsize=9)
            if i_dir == 0:
                ax.set_ylabel(f"{roi}\nΔS (N={N_hi}−N={N_lo})", fontsize=7)
            ax.set_xlabel(xlabel, fontsize=7)
            ax.grid(True, which="major", linestyle="--", linewidth=0.5, alpha=0.6)
            ax.set_axisbelow(True)
            ax.tick_params(labelsize=6)
    fig.suptitle(f"{subj} — contrast ΔS (N={N_hi}−N={N_lo}) vs {xvar}  [{title_tag}]", fontsize=10)
    fig.legend(leg_handles, leg_labels,
               loc="upper center", ncol=len(leg_labels), fontsize=7, frameon=False,
               bbox_to_anchor=(0.5, 1.0), bbox_transform=fig.transFigure)
    fig.tight_layout(rect=[0, 0, 1, 0.99])
    fig.savefig(OUT_DIR / f"contrast_vs_{xvar}_{subj}_{suffix}.png", dpi=120, bbox_inches="tight")
    plt.close(fig)

# ── generate _raw and _corr figures ───────────────────────────────────────────
all_subjs = sorted(set(k[0] for k in raw_contrast_store))
for xvar, xlabel in X_AXES:
    for subj in all_subjs:
        _plot_contrast(raw_contrast_store,  xvar, xlabel, subj, "raw",  "fit w/ RN")
        _plot_contrast(corr_contrast_store, xvar, xlabel, subj, "corr", "clean model")

print("Per-subject contrast figures saved (_raw and _corr).")
# Out:
# Per-subject contrast figures saved (_raw and _corr).
